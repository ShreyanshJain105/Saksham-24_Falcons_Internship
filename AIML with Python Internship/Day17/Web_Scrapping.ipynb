# %%
import time
import sys
from bs4 import BeautifulSoup
import requests

# %%
try:
    page=requests.get('https://www.who.int/data/gho/data/themes/air-pollution/who-air-quality-database/2022')
    
    
except Exception as e:
    print(e)
    
time.sleep(2)

soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class' :'arrowed-link'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
#  <!DOCTYPE html>
#  <html lang="en"> <head> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><title>
# 	Air quality database 2022
# </title> <link href="/favicon.ico" rel="shortcut icon"/> <link href="/manifest.json" rel="manifest"/> <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon"/> <meta content="#007eb4" name="theme-color"> <link href="https://fonts.googleapis.com" rel="preconnect"> <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"> <link crossorigin="" href="https://use.fontawesome.com" rel="preconnect"> <link href="https://cdnjs.cloudflare.com" rel="dns-prefetch"/> <link href="https://kendo.cdn.telerik.com" rel="dns-prefetch"/> <link href="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.all.min.js" rel="prefetch"/> <link href="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.timezones.min.js" rel="prefetch"/> <link href="https://cdn.who.int" rel="preconnect"> <link href="https://use.fontawesome.com/releases/v5.15.4/css/all.css" rel="stylesheet" type="text/css"> <link href="/ResourcePackages/WHO/assets/dist/styles/grid.min.css?v=14.0.7729.21936" rel="stylesheet"/> <link href="/ResourcePackages/WHO/assets/dist/styles/origin.min.css?v=14.0.7729.21936" rel="stylesheet"/><link href="/ResourcePackages/WHO/assets/dist/styles/main.min.css?v=14.0.7729.21936" rel="stylesheet"/> <link href="/ResourcePackages/WHO/assets/dist/styles/print.min.css?v=14.0.7729.21936" media="print" rel="stylesheet"/>
# <script>
#                 var lang = document.documentElement.lang;
#                 window.dataLayer = window.dataLayer || [];
#                 window.dataLayer.push({'language': lang });
#                 window.dataLayer.push({
#   "pagetype": "webpage",
#   "targetaudience": "general-audience",
#   "targetcountry": "global",
#   "publishingoffice": "environment-climate-change-and-health",
#   "healthtopic": "Airpollution"
# });</script> <script>
#                     (function() {
#                     function deleteCookie(cookieName,domain) {
#                         document.cookie = cookieName + '=;expires=Mon Jan 01 1900 00:00:00 ; path=/; domain=' + domain;
#                     }
#                     function loadAndTrack(canTrack) {
#                         if (!canTrack) {
#                             var domain = location.hostname.replace(/^www\./i, '.');
#                             //GA
#                             deleteCookie('_ga', domain);
#                             deleteCookie('_gat', domain);
#                             deleteCookie('_gid', domain);
#                             //Clarity
#                             deleteCookie('_clck', domain);
#                             deleteCookie('_clsk', domain);
#                             //Google Adsense
#                             deleteCookie('_gcl_au', domain);
#                         }
#                         else{
#                             //Fire GTM
#                             //Google Tag Manager
#                                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                                 })(window,document,'script','dataLayer','GTM-5QFSQRT');
#                             //End Google Tag Manager
#                         }
#                         return;
#                     }
#
#                     if (window.TrackingConsentManager) {
#                         TrackingConsentManager.addEventListener('ConsentChanged', loadAndTrack);
#                         loadAndTrack(TrackingConsentManager.canTrackCurrentUser());
#                     }
#                     else {
#                         loadAndTrack(true);
#                     }
#                     })();
#                 </script><meta content="en_US" property="og:locale"/><meta content="Air quality database 2022" property="og:title"/><meta content="WHO's air quality database compiles data on ground measurements of annual mean concentrations of particulate matter of a diameter equal to or smaller than 10 μm (PM10) or equal to or smaller than 2.5 μm (PM2.5) which aim at representing an average for the city or town as a whole, rather than for individual stations. The database currently hosts 4300 human settlements in 108 countries and is updated on a regular basis." property="og:description"/><style media="all" type="text/css">.zeContentMode .sfPageContainer .RadDock .rdContent,.zeLayoutMode .sfPageContainer .RadDock .rdContent,
# .zeSettingsMode .sfPageContainer .RadDock .rdContent,.zeThemesMode .sfPageContainer .RadDock .rdContent, .sfPageContainer .RadDock .rdContent a.sfAddContentLnk,
# .-sf-integrated-app body {
#     font-family: Arial, Verdana, sans-serif !important;
# }
# </style><style media="all" type="text/css">@media (min-width: 1020px) {
# .row.flex-ar {display: flex;flex-direction: row;align-content: stretch;}
# .row.flex-ar .sf_colsIn.col-sm-6.col-md-3{display:flex;flex-grow:1;;margin-bottom:2em;}
#     }
# .flex-ar img.mdc-card__media--4-3 {
#     aspect-ratio: 1/1;
# }</style><meta content="summary_large_image" name="twitter:card"/><meta content="Sitefinity 14.3.8026.0 DX" name="Generator"/><meta content="WHO's air quality database compiles data on ground measurements of annual mean concentrations of particulate matter of a diameter equal to or smaller than 10 μm (PM10) or equal to or smaller than 2.5 μm (PM2.5) which aim at representing an average for the city or town as a whole, rather than for individual stations. The database currently hosts 4300 human settlements in 108 countries and is updated on a regular basis." name="description"/></link></link></link></link></link></meta></head> <body class="sf-body "> <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5QFSQRT" style="display:none;visibility:hidden" width="0"></iframe></noscript><script src="/ScriptResource.axd?d=okuX3IVIBwfJlfEQK32K3l5K7YGiATb30h89J0olbNMeAyOtdYE6_Exv9Bd_ta2_XSFvjotxKLnlt9vcM6Kg3aKCXjsPLAfc02HCCEnrn0StjUGoNmpcNHr0Q7qewBsI-wQmYIVPg1mLq03jlrRY4M-hzwvjWouuBv3ehropIpydPBUR0&amp;t=ffffffff95aba61f" type="text/javascript"></script><script src="/ScriptResource.axd?d=ePnjFy9PuY6CB3GWMX-b_9dUqj_iyHKbtZiYzX__OhcBoGTfz1BCLaN4h7Fbajcqvr0jzshQTloWygrPD-ACaSqbbnMU2RjynHKyNq228hugZnvpXRMVXdY9OyDF4Ewext63iLJGrHIt24Ious-uCOclPLq5lpYk7ok9AjUyDR56hxVu0&amp;t=ffffffff95aba61f" type="text/javascript"></script><script src="/ScriptResource.axd?d=2z9h4-hKx8Yk1hygmet7pjkFguWG8Z1Fhnuod_CvCHCExwAB9TmazYiwtnNc8_PE_sQ84nrSkjqY9EALBnpl3lcKaF9OEQUFbopzQYCfhpJXDQLR-yvNY8t812iM5Aejg6fxAEzrTW8MI2owx-zl9SrMG73lcKP32vb5eFgX02xyZpHf0&amp;t=ffffffff95aba61f" type="text/javascript"></script> <div class="sf-main-site main-site main"> <header> <div class="sf-top-header top-header" id="sf-top-header"> <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container">
# <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="TopHeader_TD9F2A204012_Col00">
# </div>
# <div class="row" data-sf-element="Row"> <div class="sf_colsIn col-md-4" data-placeholder-label="Geo Navigation" data-sf-element="Geo Navigation">
# <div id="sf-geo-navigation-container">
# <nav class="sf-geo-navigation">
# <ul class="sf-primary-geo-navigation" id="sf-primary-geo-navigation">
# <li class="active sf-no-logo">
# <a class="mobile nav-logo" href="https://www.who.int/">
# <img alt="World Health Organization" class="svg" src="/images/default-source/fallback/header-logos/h-logo-blue.svg?sfvrsn=aaed4f35_18"/>
# </a>
# <a class="desktop" href="https://www.who.int/">Global</a>
# </li>
# <li class=" has-children">
# <a href="#">Regions</a>
# <div class="sf-secondary-geo-navigation-container">
# <div class="sf-secondary-geo-navigation-wrapper">
# <div class="sf-geo-navigation-title">
# <div class="nav-header">
# <span class="nav-logo">
# <img alt="World Health Organization" class="svg" src="/images/default-source/fallback/header-logos/h-logo-blue.svg?sfvrsn=aaed4f35_18"/>
# </span>
# <span class="nav-title">WHO Regional websites</span>
# <div class="nav-back-btn"><i class="fas fa-angle-left"></i></div>
# </div>
# </div>
# <ul class="sf-secondary-geo-navigation sf-secondary-geo-navigation-region row">
# <li class=" col-md-4">
# <a href="https://www.afro.who.int/">
# <img alt="Africa" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/africa.png?sfvrsn=3204f957_18"/>
# <span>Africa</span>
# </a>
# </li>
# <li class=" col-md-4">
# <a href="https://www.paho.org/hq/index.php?lang=en">
# <img alt="Americas" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/americas.png?sfvrsn=9efd6df3_18"/>
# <span>Americas</span>
# </a>
# </li>
# <li class=" col-md-4">
# <a href="https://www.who.int/southeastasia">
# <img alt="South-East Asia" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/south-east-asia.png?sfvrsn=68e76dc2_16"/>
# <span>South-East Asia</span>
# </a>
# </li>
# <li class=" col-md-4">
# <a href="https://www.who.int/europe/">
# <img alt="Europe" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/europe.png?sfvrsn=c7d5c5a5_18"/>
# <span>Europe</span>
# </a>
# </li>
# <li class=" col-md-4">
# <a href="http://www.emro.who.int/index.html">
# <img alt="Eastern Mediterranean" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/eastern-mediterranean.png?sfvrsn=71211e18_16"/>
# <span>Eastern Mediterranean</span>
# </a>
# </li>
# <li class=" col-md-4">
# <a href="https://www.who.int/westernpacific/">
# <img alt="Western Pacific" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/western-pacific.png?sfvrsn=88cbdcd5_16"/>
# <span>Western Pacific</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# </div> <div class="sf_colsIn col-md-8" data-placeholder-label="Language Selector &amp; Search" data-sf-element="Language Selector &amp; Search">
# <div class="form-inline">
# <div class="form-group sf-search-input-wrapper" role="search">
# <div class="srchaction-wrapper">
# <span class="srchaction">
# <i aria-hidden="true" class="fa fa-search fa-2x fa-loaded" id="a080dabf-7e7d-4c51-b3ad-98da8122559a"></i>
# </span>
# <input aria-autocomplete="both" aria-describedby="SearchInfo-1" class="form-control" id="2fdccd50-ec6f-4e75-a152-aeb8342e62a0" placeholder="Search" title="Search input" type="search" value=""/>
# </div>
# <span class="srchtoggle">
# <i aria-hidden="true" class="fa fa-search fa-2x fa-loaded"></i>
# </span>
# <span aria-hidden="true" hidden="" id="SearchInfo-1">When autocomplete results are available use up and down arrows to review and enter to select.</span>
# </div>
# <input data-sf-role="resultsUrl" type="hidden" value="/home/search"/>
# <input data-sf-role="indexCatalogue" type="hidden" value="genericsearchindex1"/>
# <input data-sf-role="wordsMode" type="hidden" value="AnyWord"/>
# <input data-sf-role="disableSuggestions" type="hidden" value="true"/>
# <input data-sf-role="minSuggestionLength" type="hidden" value="3"/>
# <input data-sf-role="suggestionFields" type="hidden" value="Title,Content"/>
# <input data-sf-role="language" type="hidden" value="en"/>
# <input data-sf-role="siteId" type="hidden" value="15210d59-ad60-47ff-a542-7ed76645f0c7"/>
# <input data-sf-role="suggestionsRoute" type="hidden" value="/restapi/search/suggestions"/>
# <input data-sf-role="searchTextBoxId" type="hidden" value="#2fdccd50-ec6f-4e75-a152-aeb8342e62a0"/>
# <input data-sf-role="searchButtonId" type="hidden" value="#a080dabf-7e7d-4c51-b3ad-98da8122559a"/>
# </div>
# <div class="dd sf-lang-selector language-selector">
# <i class="fas fa-language"></i>
# <label for="language-selector">
# Select language
# </label>
# <select id="language-selector" name="language-selector" onchange="openLink(value)">
# <option disabled="" selected="">Select language</option>
# <option class="selected" value="en">English</option>
# </select>
# <i class="fas fa-angle-down"></i>
# </div>
# <style>
# li.slicknav_addition.sf-lang-selector{width:100%;position:relative}li.slicknav_addition.sf-lang-selector select{min-width:100%}#search-form label{visibility:hidden}.language-selector label{width:0!important;height:0;display:inline-block;overflow:hidden}
# </style>
# </div> </div> </div> </div> <div class="main-header" id="sf-main-header"> <div class="container"> <div class="row" data-sf-element="Row"> <div class="sf_colsIn col-md-12" data-placeholder-label="Logos Geo Navigation" data-sf-element="Logos">
# <div class="header-logo logos-container"> <a class="primary-logo" href="/" title="Home"> <img alt="Home" class="logo svg" src="/ResourcePackages/WHO/assets/dist/images/logos/en/h-logo-blue.svg"/> </a> </div> </div> </div> </div>
# <div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="MainHeader_TEC2026FA002_Col00">
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="MainHeader_TEC2026FA002_Col01">
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="MainHeader_TEC2026FA002_Col02">
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="MainHeader_TEC2026FA002_Col03">
# </div>
# </div>
# </div> <div class="navigation" id="navigationToScrape">
# <div class="row navWrapper" data-sf-element="Row">
# <div class="nav-container">
# <ul class="nav"></ul>
# </div>
# <ul class="nav-mobile"></ul>
# <div class="sf_colsIn col-md-12" data-placeholder-label="Menu Wrapper" data-sf-element="Menu Wrapper" id="Navigation_TD9F2A204024_Col00"><div class="navItemLayout navHomeItemLayout">
# <div class="sf_colsIn col-md-12 navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204025_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/" target="_self">Home</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204025_Col01"></div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204029_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/redirect-pages/mega-menu/health-topics" target="_self">Health Topics</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204029_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_T75121FDA161_Col00"><div class="sf_colsIn horizontal" data-placeholder-label="Horizontal" data-sf-element="Horizontal" id="Navigation_TD9F2A204114_Col00">
# <div class="sf-content-block content-block">
# <div><ul><li><a href="/health-topics/">All topics »</a></li><li><a href="/health-topics/#A">A</a></li><li><a href="/health-topics/#B">B</a></li><li><a href="/health-topics/#C">C</a></li><li><a href="/health-topics/#D">D</a></li><li><a href="/health-topics/#E">E</a></li><li><a href="/health-topics/#F">F</a></li><li><a href="/health-topics/#G">G</a></li><li><a href="/health-topics/#H">H</a></li><li><a href="/health-topics/#I">I</a></li><li><a href="/health-topics/#J">J</a></li><li><a href="/health-topics/#K">K</a></li><li><a href="/health-topics/#L">L</a></li><li><a href="/health-topics/#M">M</a></li><li><a href="/health-topics/#N">N</a></li><li><a href="/health-topics/#O">O</a></li><li><a href="/health-topics/#P">P</a></li><li><a href="/health-topics/#Q">Q</a></li><li><a href="/health-topics/#R">R</a></li><li><a href="/health-topics/#S">S</a></li><li><a href="/health-topics/#T">T</a></li><li><a href="/health-topics/#U">U</a></li><li><a href="/health-topics/#V">V</a></li><li><a href="/health-topics/#W">W</a></li><li><a href="/health-topics/#X">X</a></li><li><a href="/health-topics/#Y">Y</a></li><li><a href="/health-topics/#Z">Z</a></li></ul></div>
# </div>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_T75121FDA161_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/resources" target="_self">Resources »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/resources/fact-sheets" target="_self">Fact sheets</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/resources/facts-in-pictures" target="_self">Facts in pictures</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/resources/multimedia" target="_self">Multimedia</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/resources/publications" target="_self">Publications</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/resources/questions-answers" target="_self">Questions &amp; answers</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/resources/tools-and-toolkits" target="_self">Tools and toolkits</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_T75121FDA161_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/popular" target="_self">Popular »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/popular/air-pollution" target="_self">Air pollution</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/popular/coronavirus-disease-(covid-19)" target="_self">Coronavirus disease (COVID-19)</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/popular/hepatitis" target="_self">Hepatitis</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/health-topics/popular/monkeypox" target="_self">Monkeypox</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_T75121FDA161_Col03">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204027_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/redirect-pages/mega-menu/countries" target="_self">Countries</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204027_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204039_Col00"><div class="sf_colsIn horizontal" data-placeholder-label="Horizontal" data-sf-element="Horizontal" id="Navigation_TD9F2A204043_Col00">
# <div class="sf-content-block content-block">
# <div><ul><li><a href="/countries/">All countries »</a></li><li><a href="/countries/#A">A</a></li><li><a href="/countries/#B">B</a></li><li><a href="/countries/#C">C</a></li><li><a href="/countries/#D">D</a></li><li><a href="/countries/#E">E</a></li><li><a href="/countries/#F">F</a></li><li><a href="/countries/#G">G</a></li><li><a href="/countries/#H">H</a></li><li><a href="/countries/#I">I</a></li><li><a href="/countries/#J">J</a></li><li><a href="/countries/#K ">K</a></li><li><a href="/countries/#L ">L</a></li><li><a href="/countries/#M ">M</a></li><li><a href="/countries/#N ">N</a></li><li><a href="/countries/#O ">O</a></li><li><a href="/countries/#P ">P</a></li><li><a href="/countries/#Q ">Q</a></li><li><a href="/countries/#R ">R</a></li><li><a href="/countries/#S ">S</a></li><li><a href="/countries/#T ">T</a></li><li><a href="/countries/#U ">U</a></li><li><a href="/countries/#V ">V</a></li><li><a href="/countries/#W ">W</a></li><li><a href="/countries/#X ">X</a></li><li><a href="/countries/#Y ">Y</a></li><li><a href="/countries/#Z ">Z</a></li></ul></div>
# </div>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204039_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/regions" target="_self">Regions »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/regions/africa" target="_self">Africa</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/regions/americas" target="_self">Americas</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/regions/south-east-asia" target="_self">South-East Asia</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/regions/europe" target="_self">Europe</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/regions/eastern-mediterranean" target="_self">Eastern Mediterranean</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/regions/western-pacific" target="_self">Western Pacific</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204039_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/who-in-countries" target="_self">WHO in countries »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/who-in-countries/data-statistics" target="_self">Statistics</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/who-in-countries/cooperation-strategies" target="_self">Cooperation strategies</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/countries/who-in-countries/ukraine-emergency" target="_self">Ukraine emergency</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204039_Col03">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204028_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/news-room" target="_self">Newsroom</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204028_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204038_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news" target="_self">All news »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/releases" target="_self">News releases</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/statements" target="_self">Statements</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/campaigns" target="_self">Campaigns</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/commentaries" target="_self">Commentaries</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/events" target="_self">Events</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/feature-stories" target="_self">Feature stories</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/speecheshub" target="_self">Speeches</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/spotlights" target="_self">Spotlights</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/newsletters" target="_self">Newsletters</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/photo-library" target="_blank">Photo library</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/news/all-news/media-distribution-list" target="_self">Media distribution list</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-md-6" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204038_Col01">
# <div class="sf-content-block content-block">
# <div><ul><li><a href="/news-room/headlines">Headlines »</a></li></ul></div>
# </div>
# <div class="vertical-list" id="listView"></div>
# <script id="template" type="text/x-kendo-tmpl">
#     <div class="vertical-list-item">
#         <div class="info">
#             <a href="https://www.who.int/news/item#:ItemDefaultUrl #" aria-label="#: Title #" role="link">
#                 <p class="heading">#: Title #</p>
#             </a>
#             <div class="date">
#                 <span class="timestamp">#: FormatedDate #</span>
#                 <div class="sf-tags-list">
#                     <div class="sf-tags-list-item">#: NewsType #</div>
#                 </div>
#             </div>
#         </div>
#     </div>
# </script>
# <script>
#     window.onload = function () {
#         var remoteDataSource = new kendo.data.DataSource({
#             type: "odata-v4",
#             transport: {
#                 read: "/api/news/newsitems?sf_provider=OpenAccessDataProvider&sf_culture=en&$top=3&$orderby=PublicationDateAndTime%20desc&$select=Title,ItemDefaultUrl,FormatedDate,NewsType&$filter=publishingoffices/any(s:s eq df302c0e-1f59-4efb-b276-d154122d3760)"
#             }
#         });
#         $("#listView").kendoListView({
#             dataSource: remoteDataSource,
#             pageable: true,
#             template: kendo.template($("#template").html()),
#             dataBound: function () {
#                 this.wrapper.removeClass("k-widget");
#                 this.wrapper.removeClass("k-listview");
#             }
#         });
#     };
# </script>
# </div>
# <div class="sf_colsIn col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204038_Col02">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204040_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/redirect-pages/mega-menu/emergencies" target="_self">Emergencies</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204040_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204090_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/emergencies" target="_self">Focus on »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/emergencies/afghanistan-crisis" target="_self">Afghanistan crisis</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/emergencies/novel-coronavirus-(2019-ncov)" target="_self">COVID-19 pandemic</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/emergencies/crisis-in-northern-ethiopia" target="_self">Northern Ethiopia crisis</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/emergencies/syrian-arab-republic" target="_self">Syria crisis</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/emergencies/ukraine-emergency" target="_self">Ukraine emergency</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/emergencies/monkeypox-outbreak" target="_self">Monkeypox outbreak</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/emergencies/greater-horn-of-africa-crisis" target="_self">Greater Horn of Africa crisis</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204090_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/news" target="_self">Latest »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/news/disease-outbreak-news" target="_self">Disease Outbreak News</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/news/travel--advice" target="_self">Travel advice</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/news/situation-reports" target="_self">Situation reports</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/news/weekly-epidemiological-record" target="_self">Weekly Epidemiological Record</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204090_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies" target="_self">WHO in emergencies »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/surveillance" target="_self">Surveillance</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/research-development" target="_self">Research</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/funding" target="_self">Funding</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/partners" target="_self">Partners</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/operations" target="_self">Operations</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/independent-oversight-and-advisory--committee" target="_self">Independent Oversight and Advisory Committee</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/who-s-health-emergency-appeal-2023" target="_self">WHO's Health Emergency Appeal 2023</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204090_Col03">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_T75121FDA215_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/redirect-pages/mega-menu/data" target="_self">Data</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_T75121FDA215_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_T75121FDA217_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/data/data-at-who" target="_self">Data at WHO »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/data/data-at-who/global-healthestimates" target="_self">Global Health Estimates</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/data/data-at-who/health-sdgs" target="_self">Health SDGs</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/data/data-at-who/mortality-database" target="_self">Mortality Database</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/data/data-at-who/data-collections" target="_self">Data collections</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_T75121FDA217_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/data/dashboards" target="_self">Dashboards »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/data/dashboards/covid-19-dashboard" target="_self">COVID-19 Dashboard</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/data/dashboards/triple-billiondashboard" target="_self">Triple Billion Dashboard</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/data/dashboards/health-inequality-monitor" target="_self">Health Inequality Monitor</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_T75121FDA217_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/data/highlights" target="_self">Highlights »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/data/highlights/gho" target="_self">Global Health Observatory</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/data/highlights/score" target="_self">SCORE</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/data/highlights/insights-and-visualizations" target="_self">Insights and visualizations</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/data/highlights/data-collection-tools" target="_self">Data collection tools</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_T75121FDA217_Col03">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/data/reports" target="_self">Reports »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/data/reports/world-health-statistics-2022" target="_self">World Health Statistics 2022</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/data/reports/covid-excess-deaths" target="_self">COVID excess deaths</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/data/reports/ddi-in-focus--2022" target="_self">DDI IN FOCUS: 2022</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204026_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/redirect-pages/mega-menu/about-us" target="_self">About WHO</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204026_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204035_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/about" target="_self">About WHO »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/about/people" target="_self">People</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/about/teams" target="_self">Teams</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/about/structure" target="_self">Structure</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/about/partnerships-and-collaboration" target="_self">Partnerships and collaboration</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/about/collaborating-centres" target="_self">Collaborating centres</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/about/expert-groups" target="_self">Networks, committees and advisory groups</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/about/transformation" target="_self">Transformation</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204035_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/our--work" target="_self">Our Work »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/our--work/general-programme-of-work" target="_self">General Programme of Work</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/our--work/who-academy" target="_self">WHO Academy</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/our--work/activities" target="_self">Activities</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/our--work/initiatives" target="_self">Initiatives</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204035_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/who-funding" target="_self">Funding »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/who-funding/investment-case" target="_self">Investment case</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/who-funding/who-foundation" target="_blank">WHO Foundation</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/accountability" target="_self">Accountability »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/accountability/audit" target="_self">Audit</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/accountability/budget" target="_self">Programme Budget</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/accountability/financial--statements" target="_self">Financial statements</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/accountability/programme-budget-portal" target="_blank">Programme Budget Portal</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/accountability/results-report" target="_self">Results Report</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204035_Col03">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/governance" target="_self">Governance »</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/governance/world-health-assembly" target="_self">World Health Assembly</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/governance/executive-board" target="_self">Executive Board</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/governance/election-of-director-general" target="_self">Election of Director-General</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/governance/governing-bodies-website" target="_blank">Governing Bodies website</a>
# </li>
# <li class="">
# <a href="/redirect-pages/mega-menu/about-us/governance/member-states-portal" target="_self">Member States Portal</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div> </header> <section class="sf-content content">
# <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="PageContent_TA51A0481002_Col00">
# <div>
# <ul class="sf-breadscrumb breadcrumb">
# <li><a href="/">Home</a><span>/</span></li>
# <li><a href="/data">Data</a><span>/</span></li>
# <li><a href="/data/gho">GHO</a><span>/</span></li>
# <li><a href="/data/gho/data/themes">Themes</a><span>/</span></li>
# <li><a href="/data/gho/data/themes/air-pollution">Air pollution data portal</a><span>/</span></li>
# <li><a href="/data/gho/data/themes/air-pollution/who-air-quality-database">Air quality database</a><span>/</span></li>
# <li class="active">Air quality database 2022</li>
# </ul>
# </div>
# <script type="application/ld+json">
#     {"itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.who.int","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.who.int/data","name":"Data"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.who.int/data/gho","name":"GHO"}},{"@type":"ListItem","position":4,"item":{"@id":"https://www.who.int/data/gho/data/themes","name":"Themes"}},{"@type":"ListItem","position":5,"item":{"@id":"https://www.who.int/data/gho/data/themes/air-pollution","name":"Air pollution data portal"}},{"@type":"ListItem","position":6,"item":{"@id":"https://www.who.int/data/gho/data/themes/air-pollution/who-air-quality-database","name":"Air quality database"}},{"@type":"ListItem","position":7,"item":{"@id":"https://www.who.int/data/gho/data/themes/air-pollution/who-air-quality-database/2022","name":"Air quality database 2022"}}],"itemListOrder":"ItemListOrderAscending","@context":"http://schema.org","@type":"BreadcrumbList"}
# </script>
# </div>
# <div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-12" data-placeholder-label="Body content" data-sf-element="Column 1" id="PageContent_TA51A0481001_Col00">
# <div class="hero-image--wrapper hero-image--high-wrapper high has-caption" data-url="">
# <div class="inner responsive-background-image high-1920975293">
# <img alt="" sizes="(max-width: 768px) 200px,
#                         (max-width: 1024px) 700px,
#                         (max-width: 1366px) 1000px,
#                         1920px" srcset="https://cdn.who.int/media/images/default-source/air-pollution/health-and-energy/health_energy-178346593.tmb-768v.jpg?sfvrsn=52451e19_5 768w,
#                         https://cdn.who.int/media/images/default-source/air-pollution/health-and-energy/health_energy-178346593.tmb-1024v.jpg?sfvrsn=52451e19_5 1024w,
#                         https://cdn.who.int/media/images/default-source/air-pollution/health-and-energy/health_energy-178346593.tmb-1366v.jpg?sfvrsn=52451e19_5 1366w,
#                         https://cdn.who.int/media/images/default-source/air-pollution/health-and-energy/health_energy-178346593.tmb-1920v.jpg?sfvrsn=52451e19_5 1920w"/>
# <div class="sf_colsIn container">
# <div class="hero-image--content">
# </div>
# </div>
# </div>
# <div class="sf-image-credit">
# <div class="sf-image-credit__content">
# <div class="sf-image-credit__inner">
# Pixel_B/Adobe Stock
# </div>
# </div>
# <div class="sf-image-credit__label">
# <span class="sf-image-credit__copyright">©</span>
# <span class="sf-image-credit__text">Credits </span>
# <i class="icon plus-icon"></i>
# </div>
# </div>
# <script>
#         var imageCreditClass = document.getElementsByClassName("sf-image-credit");
#
#         var preventFunction = function () {
#             event.preventDefault()
#         };
#
#         for (var i = 0; i < imageCreditClass.length; i++) {
#             imageCreditClass[i].addEventListener('click', preventFunction);;
#         }
#     </script>
# </div>
# <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="PageContent_C010_Col00"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-12" data-placeholder-label="Column 1" data-sf-element="Column 1" id="PageContent_C019_Col00">
# <div class="section-heading">
# <h1>Air quality database: Update 2022</h1>
# </div>
# </div>
# </div>
# <div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-7" data-placeholder-label="Column 1" data-sf-element="Column 1" id="PageContent_C032_Col00">
# <div class="sf-content-block content-block">
# <div><p>This database was release in April 2022 (5th edition) and the years of measurement range mostly from 2010 to 2019.</p><p>The WHO air quality database compiles data on ground measurements of annual mean concentrations of nitrogen dioxide (NO<sub>2</sub>), particulate matter of a diameter equal or smaller than 10 μm (PM<sub>10</sub>) or equal or smaller than 2.5 μm (PM<sub>2.5</sub>) which aim at representing an average for the city or town as a whole, rather than for individual stations. Both groups of pollutants originate mainly from human activities related to fossil fuel combustion.</p><p>The 2022 update (Fifth Version) database was released in April 2022 and hosts data on air quality for over 600 human settlements in more than 100 countries.</p><p>The data compiled in this database is used as input to derive the Sustainable Development Goal Indicator 11.6.2, Air quality in cities, for which WHO is custodial agency.</p><div><h2>Data sources</h2><p><span style="background-color:initial;color:#333333;font-family:inherit;font-size:inherit;text-transform:inherit;white-space:inherit;word-spacing:normal;caret-color:auto;">The primary sources of data were official reports of countries sent to WHO upon request, official national and subnational reports and national and subnational websites that contain measurements of PM10 or PM2.5 and ground measurements compiled in the framework of the Global Burden of Disease project. For NO2, ground measurements compiled for research by <a data-sf-ec-immutable="" href="https://pubs.acs.org/doi/10.1021/acs.est.7b01148" target="_blank">Larkin et al. in 2017</a> were obtained. Measurements reported by the following regional networks were also used: Clean Air for Asia, the Air quality e-reporting database of the European Environment Agency for Europe and the AirNow Programme from the United States embassies and consulates. If such official data were not available, values from UN Agencies, Development agencies and peer-reviewed journals were used. </span></p></div><p></p></div>
# </div>
# </div>
# <div class="sf_colsIn col-md-4 col-md-push-1" data-placeholder-label="Column 2" data-sf-element="Column 2" id="PageContent_C032_Col01">
# <div class="section-heading">
# <p>Related pages</p>
# </div>
# <div class="sf-content-block content-block">
# ...
# <a href="/redirect-pages/footer/regions/americas" target="_blank">Americas</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/regions/eastern-mediterranen" target="_self">Eastern Mediterranean</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/regions/europe" target="_self">Europe</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/regions/south-east-asia" target="_self">South-East Asia</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/regions/western-pacific" target="_self">Western Pacific</a>
# </li>
# </ul>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/who-policies" target="_self">Policies</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/footer/who-policies/cyber-security" target="_self">Cyber security</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/who-policies/ethics" target="_self">Ethics</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/who-policies/permissions-and-licensing" target="_self">Permissions and licensing</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/who-policies/preventing-sexual-exploitation" target="_self">Preventing sexual exploitation</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/who-policies/terms-of-use" target="_self">Terms of use</a>
# </li>
# </ul>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/about-us" target="_self">About us</a>
# <ul class="sub-level">
# <li class="">
# <a href="/redirect-pages/footer/about-us/careers" target="_self">Careers</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/about-us/library" target="_self">Library</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/about-us/procurement" target="_self">Procurement</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/about-us/publications" target="_self">Publications</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/about-us/frequently-asked-questions" target="_self">Frequently asked questions</a>
# </li>
# <li class="">
# <a href="/redirect-pages/footer/about-us/contact-us" target="_self">Contact us</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-3 col-md-3 centered-on-mobile" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Footer_T75121FDA153_Col01">
# <div class="sf-content-block content-block">
# <div><div class="button button-dark-background" style="text-align:center;"><a href="/news-room/newsletters">Subscribe to our newsletters</a></div></div>
# </div>
# </div>
# </div>
# <div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-12" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Footer_T75121FDA199_Col00">
# </div>
# </div>
# </div>
# <div class="footer-logo"> <a href="/" title="Home"> <img alt="Home" class="logo" src="/ResourcePackages/WHO/assets/dist/images/logos/en/h-logo-white.svg"/> </a> </div> </div> <div class="bottom-footer"> <div class="container"> <div class="row"> <div class="col-md-4">
# <div class="sf-content-block content-block footerlinkleft">
# <div><span class="footerlinka"><a href="/about/policies/privacy">Privacy Legal Notice</a></span></div>
# </div>
# </div> <div class="col-md-4">
# <div class="sf-content-block content-block socialmedia-icons">
# <div><a data-sf-ec-immutable="" href="https://www.youtube.com/user/who?sub_confirmation=1" target="_blank" title="Follow WHO on Youtube"><svg viewbox="0 0 576 512" xmlns="http://www.w3.org/2000/svg"><path d="M549.655 124.083c-6.281-23.65-24.787-42.276-48.284-48.597C458.781 64 288 64 288 64S117.22 64 74.629 75.486c-23.497 6.322-42.003 24.947-48.284 48.597-11.412 42.867-11.412 132.305-11.412 132.305s0 89.438 11.412 132.305c6.281 23.65 24.787 41.5 48.284 47.821C117.22 448 288 448 288 448s170.78 0 213.371-11.486c23.497-6.321 42.003-24.171 48.284-47.821 11.412-42.867 11.412-132.305 11.412-132.305s0-89.438-11.412-132.305zm-317.51 213.508V175.185l142.739 81.205-142.739 81.201z" fill="white"></path></svg></a>
# <a data-sf-ec-immutable="" href="https://twitter.com/intent/follow?source=followbutton&amp;variant=1.0&amp;screen_name=who" target="_blank" title="Follow WHO on Twitter"><svg viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><path d="M459.37 151.716c.325 4.548.325 9.097.325 13.645 0 138.72-105.583 298.558-298.558 298.558-59.452 0-114.68-17.219-161.137-47.106 8.447.974 16.568 1.299 25.34 1.299 49.055 0 94.213-16.568 130.274-44.832-46.132-.975-84.792-31.188-98.112-72.772 6.498.974 12.995 1.624 19.818 1.624 9.421 0 18.843-1.3 27.614-3.573-48.081-9.747-84.143-51.98-84.143-102.985v-1.299c13.969 7.797 30.214 12.67 47.431 13.319-28.264-18.843-46.781-51.005-46.781-87.391 0-19.492 5.197-37.36 14.294-52.954 51.655 63.675 129.3 105.258 216.365 109.807-1.624-7.797-2.599-15.918-2.599-24.04 0-57.828 46.782-104.934 104.934-104.934 30.213 0 57.502 12.67 76.67 33.137 23.715-4.548 46.456-13.32 66.599-25.34-7.798 24.366-24.366 44.833-46.132 57.827 21.117-2.273 41.584-8.122 60.426-16.243-14.292 20.791-32.161 39.308-52.628 54.253z" fill="white"></path></svg></a>
# <a data-sf-ec-immutable="" href="https://www.facebook.com/WHO" target="_blank" title="Follow WHO on Facebook"><svg viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg"><path d="M279.14 288l14.22-92.66h-88.91v-60.13c0-25.35 12.42-50.06 52.24-50.06h40.42V6.26S260.43 0 225.36 0c-73.22 0-121.08 44.38-121.08 124.72v70.62H22.89V288h81.39v224h100.17V288z" fill="white"></path></svg></a>
# <a data-sf-ec-immutable="" href="https://instagram.com/who" target="_blank" title="Follow WHO on Instagram"><svg viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path d="M224.1 141c-63.6 0-114.9 51.3-114.9 114.9s51.3 114.9 114.9 114.9S339 319.5 339 255.9 287.7 141 224.1 141zm0 189.6c-41.1 0-74.7-33.5-74.7-74.7s33.5-74.7 74.7-74.7 74.7 33.5 74.7 74.7-33.6 74.7-74.7 74.7zm146.4-194.3c0 14.9-12 26.8-26.8 26.8-14.9 0-26.8-12-26.8-26.8s12-26.8 26.8-26.8 26.8 12 26.8 26.8zm76.1 27.2c-1.7-35.9-9.9-67.7-36.2-93.9-26.2-26.2-58-34.4-93.9-36.2-37-2.1-147.9-2.1-184.9 0-35.8 1.7-67.6 9.9-93.9 36.1s-34.4 58-36.2 93.9c-2.1 37-2.1 147.9 0 184.9 1.7 35.9 9.9 67.7 36.2 93.9s58 34.4 93.9 36.2c37 2.1 147.9 2.1 184.9 0 35.9-1.7 67.7-9.9 93.9-36.2 26.2-26.2 34.4-58 36.2-93.9 2.1-37 2.1-147.8 0-184.8zM398.8 388c-7.8 19.6-22.9 34.7-42.6 42.6-29.5 11.7-99.5 9-132.1 9s-102.7 2.6-132.1-9c-19.6-7.8-34.7-22.9-42.6-42.6-11.7-29.5-9-99.5-9-132.1s-2.6-102.7 9-132.1c7.8-19.6 22.9-34.7 42.6-42.6 29.5-11.7 99.5-9 132.1-9s102.7-2.6 132.1 9c19.6 7.8 34.7 22.9 42.6 42.6 11.7 29.5 9 99.5 9 132.1s2.7 102.7-9 132.1z" fill="white"></path></svg></a>
# <a data-sf-ec-immutable="" href="https://www.linkedin.com/company/world-health-organization" target="_blank" title="Follow WHO on LinkedIn"><svg viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path d="M416 32H31.9C14.3 32 0 46.5 0 64.3v383.4C0 465.5 14.3 480 31.9 480H416c17.6 0 32-14.5 32-32.3V64.3c0-17.8-14.4-32.3-32-32.3zM135.4 416H69V202.2h66.5V416zm-33.2-243c-21.3 0-38.5-17.3-38.5-38.5S80.9 96 102.2 96c21.2 0 38.5 17.3 38.5 38.5 0 21.3-17.2 38.5-38.5 38.5zm282.1 243h-66.4V312c0-24.8-.5-56.7-34.5-56.7-34.6 0-39.9 27-39.9 54.9V416h-66.4V202.2h63.7v29.2h.9c8.9-16.8 30.6-34.5 62.9-34.5 67.2 0 79.7 44.3 79.7 101.9V416z" fill="white"></path></svg></a>
# <a data-sf-ec-immutable="" href="https://www.snapchat.com/add/who" target="_blank" title="Follow WHO on Snapchat"><svg viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><path d="M496.926,366.6c-3.373-9.176-9.8-14.086-17.112-18.153-1.376-.806-2.641-1.451-3.72-1.947-2.182-1.128-4.414-2.22-6.634-3.373-22.8-12.09-40.609-27.341-52.959-45.42a102.889,102.889,0,0,1-9.089-16.12c-1.054-3.013-1-4.724-.248-6.287a10.221,10.221,0,0,1,2.914-3.038c3.918-2.591,7.96-5.22,10.7-6.993,4.885-3.162,8.754-5.667,11.246-7.44,9.362-6.547,15.909-13.5,20-21.278a42.371,42.371,0,0,0,2.1-35.191c-6.2-16.318-21.613-26.449-40.287-26.449a55.543,55.543,0,0,0-11.718,1.24c-1.029.224-2.059.459-3.063.72.174-11.16-.074-22.94-1.066-34.534-3.522-40.758-17.794-62.123-32.674-79.16A130.167,130.167,0,0,0,332.1,36.443C309.515,23.547,283.91,17,256,17S202.6,23.547,180,36.443a129.735,129.735,0,0,0-33.281,26.783c-14.88,17.038-29.152,38.44-32.673,79.161-.992,11.594-1.24,23.435-1.079,34.533-1-.26-2.021-.5-3.051-.719a55.461,55.461,0,0,0-11.717-1.24c-18.687,0-34.125,10.131-40.3,26.449a42.423,42.423,0,0,0,2.046,35.228c4.105,7.774,10.652,14.731,20.014,21.278,2.48,1.736,6.361,4.24,11.246,7.44,2.641,1.711,6.5,4.216,10.28,6.72a11.054,11.054,0,0,1,3.3,3.311c.794,1.624.818,3.373-.36,6.6a102.02,102.02,0,0,1-8.94,15.785c-12.077,17.669-29.363,32.648-51.434,44.639C32.355,348.608,20.2,352.75,15.069,366.7c-3.868,10.528-1.339,22.506,8.494,32.6a49.137,49.137,0,0,0,12.4,9.387,134.337,134.337,0,0,0,30.342,12.139,20.024,20.024,0,0,1,6.126,2.741c3.583,3.137,3.075,7.861,7.849,14.78a34.468,34.468,0,0,0,8.977,9.127c10.019,6.919,21.278,7.353,33.207,7.811,10.776.41,22.989.881,36.939,5.481,5.778,1.91,11.78,5.605,18.736,9.92C194.842,480.951,217.707,495,255.973,495s61.292-14.123,78.118-24.428c6.907-4.24,12.872-7.9,18.489-9.758,13.949-4.613,26.163-5.072,36.939-5.481,11.928-.459,23.187-.893,33.206-7.812a34.584,34.584,0,0,0,10.218-11.16c3.434-5.84,3.348-9.919,6.572-12.771a18.971,18.971,0,0,1,5.753-2.629A134.893,134.893,0,0,0,476.02,408.71a48.344,48.344,0,0,0,13.019-10.193l.124-.149C498.389,388.5,500.708,376.867,496.926,366.6Zm-34.013,18.277c-20.745,11.458-34.533,10.23-45.259,17.137-9.114,5.865-3.72,18.513-10.342,23.076-8.134,5.617-32.177-.4-63.239,9.858-25.618,8.469-41.961,32.822-88.038,32.822s-62.036-24.3-88.076-32.884c-31-10.255-55.092-4.241-63.239-9.858-6.609-4.563-1.24-17.211-10.341-23.076-10.739-6.907-24.527-5.679-45.26-17.075-13.206-7.291-5.716-11.8-1.314-13.937,75.143-36.381,87.133-92.552,87.666-96.719.645-5.046,1.364-9.014-4.191-14.148-5.369-4.96-29.189-19.7-35.8-24.316-10.937-7.638-15.748-15.264-12.2-24.638,2.48-6.485,8.531-8.928,14.879-8.928a27.643,27.643,0,0,1,5.965.67c12,2.6,23.659,8.617,30.392,10.242a10.749,10.749,0,0,0,2.48.335c3.6,0,4.86-1.811,4.612-5.927-.768-13.132-2.628-38.725-.558-62.644,2.84-32.909,13.442-49.215,26.04-63.636,6.051-6.932,34.484-36.976,88.857-36.976s82.88,29.92,88.931,36.827c12.611,14.421,23.225,30.727,26.04,63.636,2.071,23.919.285,49.525-.558,62.644-.285,4.327,1.017,5.927,4.613,5.927a10.648,10.648,0,0,0,2.48-.335c6.745-1.624,18.4-7.638,30.4-10.242a27.641,27.641,0,0,1,5.964-.67c6.386,0,12.4,2.48,14.88,8.928,3.546,9.374-1.24,17-12.189,24.639-6.609,4.612-30.429,19.343-35.8,24.315-5.568,5.134-4.836,9.1-4.191,14.149.533,4.228,12.511,60.4,87.666,96.718C468.629,373.011,476.119,377.524,462.913,384.877Z" fill="white"></path></svg></a>
# <a data-sf-ec-immutable="" href="https://www.tiktok.com/@who?lang=en" target="_blank" title="Follow WHO on TikTok"><svg viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path d="M448,209.91a210.06,210.06,0,0,1-122.77-39.25V349.38A162.55,162.55,0,1,1,185,188.31V278.2a74.62,74.62,0,1,0,52.23,71.18V0l88,0a121.18,121.18,0,0,0,1.86,22.17h0A122.18,122.18,0,0,0,381,102.39a121.43,121.43,0,0,0,67,20.14Z" fill="white"></path></svg></a></div>
# </div>
# </div> <div class="col-md-4 copyright"> <span>
# ©
# </span>
# 2023
# <div class="sf-content-block content-block">
# <div><a href="/about/policies/terms-of-use">WHO</a></div>
# </div>
# </div> </div> </div> </div> </footer> </div> <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script>
#         window.__define = window.define;
#         window.__require = window.require;
#         window.define = undefined;
#         window.require = undefined;
#     </script> <script src="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.all.min.js" type="text/javascript"></script><script src="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.timezones.min.js" type="text/javascript"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/gsap.min.js" type="text/javascript"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/ScrollTrigger.min.js" type="text/javascript"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/ScrollToPlugin.min.js" type="text/javascript"></script><script src="/ResourcePackages/WHO/assets/dist/scripts/parallax.min.js?package=WHO" type="text/javascript"></script><script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend.Search/Mvc/Scripts/SearchBox/Search-box.min.js?package=WHO&amp;v=OTk4MDgwOTIw" type="text/javascript"></script><script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend.Navigation/Mvc/Scripts/LanguageSelector/language-selector.min.js?package=WHO&amp;v=MTQuMy44MDI2LjA%3d" type="text/javascript"></script><script src="/Mvc/Scripts/ContentBlock/content-block.min.js?package=WHO" type="text/javascript"></script><script src="/Mvc/Scripts/HeroImage/responsive-background-image.min.js?package=WHO" type="text/javascript"></script><script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend/Mvc/Scripts/GHO/utils.min.js?package=WHO&amp;v=LTY1ODA2NjUzNQ%3d%3d" type="text/javascript"></script><script id="PersonalizationTracker" type="application/json">
# 	{"IsPagePersonalizationTarget":false,"IsUrlPersonalizationTarget":false,"PageId":"6543db4e-ce8c-4a69-8f0f-f205195f7488"}
# </script><script src="/WebResource.axd?d=Oiw5o8i74rDb2VpVaCaMStPoJ1dBeSniQ1UcN-tajp7S6UQI4QFVCojlg1ewuf339ZIyq0NtnQlSiEw1RQXcWIVwl_-LxzVLlNCkT-5fM3qvVhZCKMRq6X6cWc42Aw4Db6sa87yi7j5Hio4wozQZMklgyIbXX4yGQn_Sh0nCPeRw8nypcGpUIdT0MqtRIOGgRLfw327mU3tc3-bA3UOOd_v176Q1&amp;t=638156688400000000" type="text/javascript">
# </script><input data-sf-role="en" type="hidden" value="https://www.who.int/data/gho/data/themes/air-pollution/who-air-quality-database/2022"/> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/slicknav.min.js?v=14.0.7729.21936" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/auto-complete.min.js?v=14.0.7729.21936" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/match-height.min.js?v=14.0.7729.21936" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/lazy.min.js?v=14.0.7729.21936" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/modernizr-custom.js?v=14.0.7729.21936" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/select2.full.min.js?v=14.0.7729.21936" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/accordion-footer-list.min.js?v=14.0.7729.21936" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/main.min.js?v=14.0.7729.21936" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/main-navigation.min.js?v=14.0.7729.21936" type="text/javascript"></script><script src="/ResourcePackages/WHO/assets/dist/scripts/geo-navigation.min.js?v=14.0.7729.21936" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/image-resolution.min.js?v=14.0.7729.21936" type="text/javascript"></script> <script type="application/ld+json">
#             {
#             "@context": "http://schema.org",
#             "@type": "WebPage",
#             "name": "Air quality database 2022",
#             "description": "WHO&#39;s air quality database compiles data on ground measurements of annual mean concentrations of particulate matter of a diameter equal to or smaller than 10 μm (PM10) or equal to or smaller than 2.5 μm (PM2.5) which aim at representing an average for the city or town as a whole, rather than for individual stations. The database currently hosts 4300 human settlements in 108 countries and is updated on a regular basis."
#             }
#         </script> <script>
#         // Picture element HTML5 shiv
#         document.createElement("picture");
#     </script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/picturefill.min.js?v=14.0.7729.21936" type="text/javascript"></script> <script>
#         window.define = window.__define;
#         window.require = window.__require;
#         window.__define = undefined;
#         window.__require = undefined;
#     </script> </body> </html>

# %%
links
# Out:
# [<div class="arrowed-link"><a href="/data/gho/data/themes/air-pollution/who-air-quality-database" target="_blank">Air quality database - current version</a></div>,
#  <div class="arrowed-link"><a href="/data/gho/data/themes/air-pollution/who-air-quality-database/2018" target="_blank">Air quality database 2018</a></div>,
#  <div class="arrowed-link"><a href="/data/gho/data/themes/air-pollution/who-air-quality-database/2016" target="_blank">Air quality database 2016</a></div>,
#  <div class="arrowed-link"><a data-sf-ec-immutable="" data-sf-marked="" href="/data/gho/data/themes/air-pollution/who-air-quality-database/2014" target="_blank">Air quality database 2014</a></div>,
#  <div class="arrowed-link"><a data-sf-ec-immutable="" data-sf-marked="" href="/data/gho/data/themes/air-pollution/who-air-quality-database/2011" target="_blank">Air quality database 2011</a></div>,
#  <div class="arrowed-link"><a href="/data/gho/data/themes/air-pollution/ambient-air-pollution" target="_blank">Ambient air pollution data</a></div>,
#  <div class="arrowed-link"><a data-sf-ec-immutable="" href="https://whoairquality.shinyapps.io/AirQualityStandards/">Air quality standards tool</a></div>,
#  <div class="arrowed-link"><a data-sf-ec-immutable="" href="https://www.euro.who.int/en/health-topics/environment-and-health/air-quality/activities/airq-software-tool-for-health-risk-assessment-of-air-pollution">AirQ+ tool</a></div>,
#  <div class="arrowed-link">
#  <a href="/teams/environment-climate-change-and-health/air-quality-and-health">Air quality and health</a>
#  </div>,
#  <div class="arrowed-link">
#  <a href="/teams/environment-climate-change-and-health">Environment, Climate Change and Health</a>
#  </div>,
#  <div class="arrowed-link"><a data-sf-ec-immutable="" data-sf-marked="" href="https://public.wmo.int/en/programmes/global-atmosphere-watch-programme" target="_blank">WMO Global Atmospheric Watch</a></div>,
#  <div class="arrowed-link"><a data-sf-ec-immutable="" data-sf-marked="" href="https://www.unep.org/explore-topics/air/what-we-do/taking-stock-global-efforts/actions-air-quality-report-update" target="_blank">UNEP Actions on Air Quality</a></div>,
#  <div class="arrowed-link"><a data-sf-ec-immutable="" data-sf-marked="" href="https://wedocs.unep.org/handle/20.500.11822/36666;jsessionid=885D5E497D4A480AA0E29DD166DCBB3B" target="_blank">UNEP Regulating Air Quality</a></div>,
#  <div class="arrowed-link"><a data-sf-ec-immutable="" data-sf-marked="" href="https://www.ccacoalition.org/en/resources/air-pollution-asia-and-pacific-science-based-solutions-summary-full-report" target="_blank">CCAC: Air Pollution in Asia and the Pacific: Science-based solutions</a></div>,
#  <div class="arrowed-link"><a data-sf-ec-immutable="" data-sf-marked="" href="https://unece.org/fileadmin/DAM/env/documents/2016/AIR/Publications/ECE_EB.AIR_138_En.pdf" target="_blank">UNECE Guidance Document on Emission Control Techniques for Mobile Sources Under the Convention on Long-range Transboundary Air Pollution</a></div>,
#  <div class="arrowed-link"><a data-sf-ec-immutable="" data-sf-marked="" href="https://www.eea.europa.eu/publications/air-quality-in-europe-2021" target="_blank">European Environment Agency - Air Quality in Europe</a></div>]

# %%
#data_link=soup.find_all('div',attrs={'class' :'arrowed-link'})

links[0]
# Out:
# <div class="arrowed-link"><a href="/data/gho/data/themes/air-pollution/who-air-quality-database" target="_blank">Air quality database - current version</a></div>

# %%
links[0].text
# Out:
# 'Air quality database - current version'

# %%
links[0].a
# Out:
# <a href="/data/gho/data/themes/air-pollution/who-air-quality-database" target="_blank">Air quality database - current version</a>

# %%
data_link=links[0].a['href']

# %%
data_link
# Out:
# '/data/gho/data/themes/air-pollution/who-air-quality-database'

# %%
import pandas as pd


'https://www.who.int' + data_link
# Out:
# 'https://www.who.int/data/gho/data/themes/air-pollution/who-air-quality-database'

# %%
soup2=BeautifulSoup(page.text,'html.parser')
#links1=soup.find_all('div',attrs={'class' :'sf-content-block content-block'})
links2=soup2.find_all('p',attrs={'class' :''})

# %%
 print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Air quality database 2022
#   </title>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon"/>
#   <meta content="#007eb4" name="theme-color">
#    <link href="https://fonts.googleapis.com" rel="preconnect">
#     <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect">
#      <link crossorigin="" href="https://use.fontawesome.com" rel="preconnect">
#       <link href="https://cdnjs.cloudflare.com" rel="dns-prefetch"/>
#       <link href="https://kendo.cdn.telerik.com" rel="dns-prefetch"/>
#       <link href="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.all.min.js" rel="prefetch"/>
#       <link href="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.timezones.min.js" rel="prefetch"/>
#       <link href="https://cdn.who.int" rel="preconnect">
#        <link href="https://use.fontawesome.com/releases/v5.15.4/css/all.css" rel="stylesheet" type="text/css">
#         <link href="/ResourcePackages/WHO/assets/dist/styles/grid.min.css?v=14.0.7729.21936" rel="stylesheet"/>
#         <link href="/ResourcePackages/WHO/assets/dist/styles/origin.min.css?v=14.0.7729.21936" rel="stylesheet"/>
#         <link href="/ResourcePackages/WHO/assets/dist/styles/main.min.css?v=14.0.7729.21936" rel="stylesheet"/>
#         <link href="/ResourcePackages/WHO/assets/dist/styles/print.min.css?v=14.0.7729.21936" media="print" rel="stylesheet"/>
#         <script>
#          var lang = document.documentElement.lang;
#                 window.dataLayer = window.dataLayer || [];
#                 window.dataLayer.push({'language': lang });
#                 window.dataLayer.push({
#   "pagetype": "webpage",
#   "targetaudience": "general-audience",
#   "targetcountry": "global",
#   "publishingoffice": "environment-climate-change-and-health",
#   "healthtopic": "Airpollution"
# });
#         </script>
#         <script>
#          (function() {
#                     function deleteCookie(cookieName,domain) {
#                         document.cookie = cookieName + '=;expires=Mon Jan 01 1900 00:00:00 ; path=/; domain=' + domain;
#                     }
#                     function loadAndTrack(canTrack) {
#                         if (!canTrack) {
#                             var domain = location.hostname.replace(/^www\./i, '.');
#                             //GA
#                             deleteCookie('_ga', domain);
#                             deleteCookie('_gat', domain);
#                             deleteCookie('_gid', domain);
#                             //Clarity
#                             deleteCookie('_clck', domain);
#                             deleteCookie('_clsk', domain);
#                             //Google Adsense
#                             deleteCookie('_gcl_au', domain);
#                         }
#                         else{
#                             //Fire GTM
#                             //Google Tag Manager
#                                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                                 })(window,document,'script','dataLayer','GTM-5QFSQRT');
#                             //End Google Tag Manager
#                         }
#                         return;
#                     }
#
#                     if (window.TrackingConsentManager) {
#                         TrackingConsentManager.addEventListener('ConsentChanged', loadAndTrack);
#                         loadAndTrack(TrackingConsentManager.canTrackCurrentUser());
#                     }
#                     else {
#                         loadAndTrack(true);
#                     }
#                     })();
#         </script>
#         <meta content="en_US" property="og:locale"/>
#         <meta content="Air quality database 2022" property="og:title"/>
#         <meta content="WHO's air quality database compiles data on ground measurements of annual mean concentrations of particulate matter of a diameter equal to or smaller than 10 μm (PM10) or equal to or smaller than 2.5 μm (PM2.5) which aim at representing an average for the city or town as a whole, rather than for individual stations. The database currently hosts 4300 human settlements in 108 countries and is updated on a regular basis." property="og:description"/>
#         <style media="all" type="text/css">
#          .zeContentMode .sfPageContainer .RadDock .rdContent,.zeLayoutMode .sfPageContainer .RadDock .rdContent,
# .zeSettingsMode .sfPageContainer .RadDock .rdContent,.zeThemesMode .sfPageContainer .RadDock .rdContent, .sfPageContainer .RadDock .rdContent a.sfAddContentLnk,
# .-sf-integrated-app body {
#     font-family: Arial, Verdana, sans-serif !important;
# }
#         </style>
#         <style media="all" type="text/css">
#          @media (min-width: 1020px) {
# .row.flex-ar {display: flex;flex-direction: row;align-content: stretch;}
# .row.flex-ar .sf_colsIn.col-sm-6.col-md-3{display:flex;flex-grow:1;;margin-bottom:2em;}
#     }
# .flex-ar img.mdc-card__media--4-3 {
#     aspect-ratio: 1/1;
# }
#         </style>
#         <meta content="summary_large_image" name="twitter:card"/>
#         <meta content="Sitefinity 14.3.8026.0 DX" name="Generator"/>
#         <meta content="WHO's air quality database compiles data on ground measurements of annual mean concentrations of particulate matter of a diameter equal to or smaller than 10 μm (PM10) or equal to or smaller than 2.5 μm (PM2.5) which aim at representing an average for the city or town as a whole, rather than for individual stations. The database currently hosts 4300 human settlements in 108 countries and is updated on a regular basis." name="description"/>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="sf-body ">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5QFSQRT" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script src="/ScriptResource.axd?d=okuX3IVIBwfJlfEQK32K3l5K7YGiATb30h89J0olbNMeAyOtdYE6_Exv9Bd_ta2_XSFvjotxKLnlt9vcM6Kg3aKCXjsPLAfc02HCCEnrn0StjUGoNmpcNHr0Q7qewBsI-wQmYIVPg1mLq03jlrRY4M-hzwvjWouuBv3ehropIpydPBUR0&amp;t=ffffffff95aba61f" type="text/javascript">
#   </script>
#   <script src="/ScriptResource.axd?d=ePnjFy9PuY6CB3GWMX-b_9dUqj_iyHKbtZiYzX__OhcBoGTfz1BCLaN4h7Fbajcqvr0jzshQTloWygrPD-ACaSqbbnMU2RjynHKyNq228hugZnvpXRMVXdY9OyDF4Ewext63iLJGrHIt24Ious-uCOclPLq5lpYk7ok9AjUyDR56hxVu0&amp;t=ffffffff95aba61f" type="text/javascript">
#   </script>
#   <script src="/ScriptResource.axd?d=2z9h4-hKx8Yk1hygmet7pjkFguWG8Z1Fhnuod_CvCHCExwAB9TmazYiwtnNc8_PE_sQ84nrSkjqY9EALBnpl3lcKaF9OEQUFbopzQYCfhpJXDQLR-yvNY8t812iM5Aejg6fxAEzrTW8MI2owx-zl9SrMG73lcKP32vb5eFgX02xyZpHf0&amp;t=ffffffff95aba61f" type="text/javascript">
#   </script>
#   <div class="sf-main-site main-site main">
#    <header>
#     <div class="sf-top-header top-header" id="sf-top-header">
#      <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container">
#       <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="TopHeader_TD9F2A204012_Col00">
#       </div>
#       <div class="row" data-sf-element="Row">
#        <div class="sf_colsIn col-md-4" data-placeholder-label="Geo Navigation" data-sf-element="Geo Navigation">
#         <div id="sf-geo-navigation-container">
#          <nav class="sf-geo-navigation">
#           <ul class="sf-primary-geo-navigation" id="sf-primary-geo-navigation">
#            <li class="active sf-no-logo">
#             <a class="mobile nav-logo" href="https://www.who.int/">
#              <img alt="World Health Organization" class="svg" src="/images/default-source/fallback/header-logos/h-logo-blue.svg?sfvrsn=aaed4f35_18"/>
#             </a>
#             <a class="desktop" href="https://www.who.int/">
#              Global
#             </a>
#            </li>
#            <li class=" has-children">
#             <a href="#">
#              Regions
#             </a>
#             <div class="sf-secondary-geo-navigation-container">
#              <div class="sf-secondary-geo-navigation-wrapper">
#               <div class="sf-geo-navigation-title">
#                <div class="nav-header">
#                 <span class="nav-logo">
#                  <img alt="World Health Organization" class="svg" src="/images/default-source/fallback/header-logos/h-logo-blue.svg?sfvrsn=aaed4f35_18"/>
#                 </span>
#                 <span class="nav-title">
#                  WHO Regional websites
#                 </span>
#                 <div class="nav-back-btn">
#                  <i class="fas fa-angle-left">
#                  </i>
#                 </div>
#                </div>
#               </div>
#               <ul class="sf-secondary-geo-navigation sf-secondary-geo-navigation-region row">
#                <li class=" col-md-4">
#                 <a href="https://www.afro.who.int/">
#                  <img alt="Africa" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/africa.png?sfvrsn=3204f957_18"/>
#                  <span>
#                   Africa
#                  </span>
#                 </a>
#                </li>
#                <li class=" col-md-4">
#                 <a href="https://www.paho.org/hq/index.php?lang=en">
#                  <img alt="Americas" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/americas.png?sfvrsn=9efd6df3_18"/>
#                  <span>
#                   Americas
#                  </span>
#                 </a>
#                </li>
#                <li class=" col-md-4">
#                 <a href="https://www.who.int/southeastasia">
#                  <img alt="South-East Asia" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/south-east-asia.png?sfvrsn=68e76dc2_16"/>
#                  <span>
#                   South-East Asia
#                  </span>
#                 </a>
#                </li>
#                <li class=" col-md-4">
#                 <a href="https://www.who.int/europe/">
#                  <img alt="Europe" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/europe.png?sfvrsn=c7d5c5a5_18"/>
#                  <span>
#                   Europe
#                  </span>
#                 </a>
#                </li>
#                <li class=" col-md-4">
#                 <a href="http://www.emro.who.int/index.html">
#                  <img alt="Eastern Mediterranean" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/eastern-mediterranean.png?sfvrsn=71211e18_16"/>
#                  <span>
#                   Eastern Mediterranean
#                  </span>
#                 </a>
#                </li>
#                <li class=" col-md-4">
#                 <a href="https://www.who.int/westernpacific/">
#                  <img alt="Western Pacific" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/western-pacific.png?sfvrsn=88cbdcd5_16"/>
#                  <span>
#                   Western Pacific
#                  </span>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </li>
#           </ul>
#          </nav>
#         </div>
#        </div>
#        <div class="sf_colsIn col-md-8" data-placeholder-label="Language Selector &amp; Search" data-sf-element="Language Selector &amp; Search">
#         <div class="form-inline">
#          <div class="form-group sf-search-input-wrapper" role="search">
#           <div class="srchaction-wrapper">
#            <span class="srchaction">
#             <i aria-hidden="true" class="fa fa-search fa-2x fa-loaded" id="a080dabf-7e7d-4c51-b3ad-98da8122559a">
#             </i>
#            </span>
#            <input aria-autocomplete="both" aria-describedby="SearchInfo-1" class="form-control" id="2fdccd50-ec6f-4e75-a152-aeb8342e62a0" placeholder="Search" title="Search input" type="search" value=""/>
#           </div>
#           <span class="srchtoggle">
#            <i aria-hidden="true" class="fa fa-search fa-2x fa-loaded">
#            </i>
#           </span>
#           <span aria-hidden="true" hidden="" id="SearchInfo-1">
#            When autocomplete results are available use up and down arrows to review and enter to select.
#           </span>
#          </div>
#          <input data-sf-role="resultsUrl" type="hidden" value="/home/search"/>
#          <input data-sf-role="indexCatalogue" type="hidden" value="genericsearchindex1"/>
#          <input data-sf-role="wordsMode" type="hidden" value="AnyWord"/>
#          <input data-sf-role="disableSuggestions" type="hidden" value="true"/>
#          <input data-sf-role="minSuggestionLength" type="hidden" value="3"/>
#          <input data-sf-role="suggestionFields" type="hidden" value="Title,Content"/>
#          <input data-sf-role="language" type="hidden" value="en"/>
#          <input data-sf-role="siteId" type="hidden" value="15210d59-ad60-47ff-a542-7ed76645f0c7"/>
#          <input data-sf-role="suggestionsRoute" type="hidden" value="/restapi/search/suggestions"/>
#          <input data-sf-role="searchTextBoxId" type="hidden" value="#2fdccd50-ec6f-4e75-a152-aeb8342e62a0"/>
#          <input data-sf-role="searchButtonId" type="hidden" value="#a080dabf-7e7d-4c51-b3ad-98da8122559a"/>
#         </div>
#         <div class="dd sf-lang-selector language-selector">
#          <i class="fas fa-language">
#          </i>
#          <label for="language-selector">
#           Select language
#          </label>
#          <select id="language-selector" name="language-selector" onchange="openLink(value)">
#           <option disabled="" selected="">
#            Select language
#           </option>
#           <option class="selected" value="en">
#            English
#           </option>
#          </select>
#          <i class="fas fa-angle-down">
#          </i>
#         </div>
#         <style>
#          li.slicknav_addition.sf-lang-selector{width:100%;position:relative}li.slicknav_addition.sf-lang-selector select{min-width:100%}#search-form label{visibility:hidden}.language-selector label{width:0!important;height:0;display:inline-block;overflow:hidden}
#         </style>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="main-header" id="sf-main-header">
#      <div class="container">
#       <div class="row" data-sf-element="Row">
#        <div class="sf_colsIn col-md-12" data-placeholder-label="Logos Geo Navigation" data-sf-element="Logos">
#         <div class="header-logo logos-container">
#          <a class="primary-logo" href="/" title="Home">
#           <img alt="Home" class="logo svg" src="/ResourcePackages/WHO/assets/dist/images/logos/en/h-logo-blue.svg"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row" data-sf-element="Row">
#       <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="MainHeader_TEC2026FA002_Col00">
#       </div>
#       <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="MainHeader_TEC2026FA002_Col01">
#       </div>
#       <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="MainHeader_TEC2026FA002_Col02">
#       </div>
#       <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="MainHeader_TEC2026FA002_Col03">
#       </div>
#      </div>
#     </div>
#     <div class="navigation" id="navigationToScrape">
#      <div class="row navWrapper" data-sf-element="Row">
#       <div class="nav-container">
#        <ul class="nav">
#        </ul>
#       </div>
#       <ul class="nav-mobile">
#       </ul>
#       <div class="sf_colsIn col-md-12" data-placeholder-label="Menu Wrapper" data-sf-element="Menu Wrapper" id="Navigation_TD9F2A204024_Col00">
#        <div class="navItemLayout navHomeItemLayout">
#         <div class="sf_colsIn col-md-12 navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204025_Col00">
#          <nav role="navigation">
#           <ul class="main-navigation">
#            <li class="">
#             <a href="/" target="_self">
#              Home
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#         <div class="container">
#          <div class="row">
#           <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204025_Col01">
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="navItemLayout">
#         <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204029_Col00">
#          <nav role="navigation">
#           <ul class="main-navigation">
#            <li class="">
#             <a href="/redirect-pages/mega-menu/health-topics" target="_self">
#              Health Topics
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#         <div class="container">
#          <div class="row">
#           <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204029_Col01">
#            <div class="row" data-sf-element="Row">
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_T75121FDA161_Col00">
#              <div class="sf_colsIn horizontal" data-placeholder-label="Horizontal" data-sf-element="Horizontal" id="Navigation_TD9F2A204114_Col00">
#               <div class="sf-content-block content-block">
#                <div>
#                 <ul>
#                  <li>
#                   <a href="/health-topics/">
#                    All topics »
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#A">
#                    A
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#B">
#                    B
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#C">
#                    C
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#D">
#                    D
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#E">
#                    E
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#F">
#                    F
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#G">
#                    G
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#H">
#                    H
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#I">
#                    I
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#J">
#                    J
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#K">
#                    K
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#L">
#                    L
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#M">
#                    M
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#N">
#                    N
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#O">
#                    O
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#P">
#                    P
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#Q">
#                    Q
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#R">
#                    R
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#S">
#                    S
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#T">
#                    T
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#U">
#                    U
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#V">
#                    V
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#W">
#                    W
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#X">
#                    X
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#Y">
#                    Y
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/health-topics/#Z">
#                    Z
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_T75121FDA161_Col01">
#              <div class="main-navigation--wrapper">
#               <ul class="main-navigation navVertical">
#                <li class="">
#                 <a href="/redirect-pages/mega-menu/health-topics/resources" target="_self">
#                  Resources »
#                 </a>
#                 <ul class="sub-level">
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/health-topics/resources/fact-sheets" target="_self">
#                    Fact sheets
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/health-topics/resources/facts-in-pictures" target="_self">
#                    Facts in pictures
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/health-topics/resources/multimedia" target="_self">
#                    Multimedia
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/health-topics/resources/publications" target="_self">
#                    Publications
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/health-topics/resources/questions-answers" target="_self">
#                    Questions &amp; answers
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/health-topics/resources/tools-and-toolkits" target="_self">
#                    Tools and toolkits
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_T75121FDA161_Col02">
#              <div class="main-navigation--wrapper">
#               <ul class="main-navigation navVertical">
#                <li class="">
#                 <a href="/redirect-pages/mega-menu/health-topics/popular" target="_self">
#                  Popular »
#                 </a>
#                 <ul class="sub-level">
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/health-topics/popular/air-pollution" target="_self">
#                    Air pollution
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/health-topics/popular/coronavirus-disease-(covid-19)" target="_self">
#                    Coronavirus disease (COVID-19)
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/health-topics/popular/hepatitis" target="_self">
#                    Hepatitis
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/health-topics/popular/monkeypox" target="_self">
#                    Monkeypox
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_T75121FDA161_Col03">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="navItemLayout">
#         <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204027_Col00">
#          <nav role="navigation">
#           <ul class="main-navigation">
#            <li class="">
#             <a href="/redirect-pages/mega-menu/countries" target="_self">
#              Countries
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#         <div class="container">
#          <div class="row">
#           <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204027_Col01">
#            <div class="row" data-sf-element="Row">
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204039_Col00">
#              <div class="sf_colsIn horizontal" data-placeholder-label="Horizontal" data-sf-element="Horizontal" id="Navigation_TD9F2A204043_Col00">
#               <div class="sf-content-block content-block">
#                <div>
#                 <ul>
#                  <li>
#                   <a href="/countries/">
#                    All countries »
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#A">
#                    A
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#B">
#                    B
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#C">
#                    C
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#D">
#                    D
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#E">
#                    E
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#F">
#                    F
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#G">
#                    G
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#H">
#                    H
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#I">
#                    I
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#J">
#                    J
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#K ">
#                    K
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#L ">
#                    L
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#M ">
#                    M
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#N ">
#                    N
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#O ">
#                    O
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#P ">
#                    P
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#Q ">
#                    Q
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#R ">
#                    R
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#S ">
#                    S
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#T ">
#                    T
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#U ">
#                    U
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#V ">
#                    V
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#W ">
#                    W
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#X ">
#                    X
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#Y ">
#                    Y
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/countries/#Z ">
#                    Z
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204039_Col01">
#              <div class="main-navigation--wrapper">
#               <ul class="main-navigation navVertical">
#                <li class="">
#                 <a href="/redirect-pages/mega-menu/countries/regions" target="_self">
#                  Regions »
#                 </a>
#                 <ul class="sub-level">
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/countries/regions/africa" target="_self">
#                    Africa
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/countries/regions/americas" target="_self">
#                    Americas
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/countries/regions/south-east-asia" target="_self">
#                    South-East Asia
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/countries/regions/europe" target="_self">
#                    Europe
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/countries/regions/eastern-mediterranean" target="_self">
#                    Eastern Mediterranean
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/countries/regions/western-pacific" target="_self">
#                    Western Pacific
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204039_Col02">
#              <div class="main-navigation--wrapper">
#               <ul class="main-navigation navVertical">
#                <li class="">
#                 <a href="/redirect-pages/mega-menu/countries/who-in-countries" target="_self">
#                  WHO in countries »
#                 </a>
#                 <ul class="sub-level">
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/countries/who-in-countries/data-statistics" target="_self">
#                    Statistics
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/countries/who-in-countries/cooperation-strategies" target="_self">
#                    Cooperation strategies
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/countries/who-in-countries/ukraine-emergency" target="_self">
#                    Ukraine emergency
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204039_Col03">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="navItemLayout">
#         <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204028_Col00">
#          <nav role="navigation">
#           <ul class="main-navigation">
#            <li class="">
#             <a href="/news-room" target="_self">
#              Newsroom
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#         <div class="container">
#          <div class="row">
#           <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204028_Col01">
#            <div class="row" data-sf-element="Row">
#             <div class="sf_colsIn col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204038_Col00">
#              <div class="main-navigation--wrapper">
#               <ul class="main-navigation navVertical">
#                <li class="">
#                 <a href="/redirect-pages/mega-menu/news/all-news" target="_self">
#                  All news »
#                 </a>
#                 <ul class="sub-level">
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/releases" target="_self">
#                    News releases
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/statements" target="_self">
#                    Statements
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/campaigns" target="_self">
#                    Campaigns
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/commentaries" target="_self">
#                    Commentaries
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/events" target="_self">
#                    Events
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/feature-stories" target="_self">
#                    Feature stories
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/speecheshub" target="_self">
#                    Speeches
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/spotlights" target="_self">
#                    Spotlights
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/newsletters" target="_self">
#                    Newsletters
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/photo-library" target="_blank">
#                    Photo library
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/news/all-news/media-distribution-list" target="_self">
#                    Media distribution list
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="sf_colsIn col-md-6" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204038_Col01">
#              <div class="sf-content-block content-block">
#               <div>
#                <ul>
#                 <li>
#                  <a href="/news-room/headlines">
#                   Headlines »
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#              <div class="vertical-list" id="listView">
#              </div>
#              <script id="template" type="text/x-kendo-tmpl">
#               <div class="vertical-list-item">
#         <div class="info">
#             <a href="https://www.who.int/news/item#:ItemDefaultUrl #" aria-label="#: Title #" role="link">
#                 <p class="heading">#: Title #</p>
#             </a>
#             <div class="date">
#                 <span class="timestamp">#: FormatedDate #</span>
#                 <div class="sf-tags-list">
#                     <div class="sf-tags-list-item">#: NewsType #</div>
#                 </div>
#             </div>
#         </div>
#     </div>
#              </script>
#              <script>
#               window.onload = function () {
#         var remoteDataSource = new kendo.data.DataSource({
#             type: "odata-v4",
#             transport: {
#                 read: "/api/news/newsitems?sf_provider=OpenAccessDataProvider&sf_culture=en&$top=3&$orderby=PublicationDateAndTime%20desc&$select=Title,ItemDefaultUrl,FormatedDate,NewsType&$filter=publishingoffices/any(s:s eq df302c0e-1f59-4efb-b276-d154122d3760)"
#             }
#         });
#         $("#listView").kendoListView({
#             dataSource: remoteDataSource,
#             pageable: true,
#             template: kendo.template($("#template").html()),
#             dataBound: function () {
#                 this.wrapper.removeClass("k-widget");
#                 this.wrapper.removeClass("k-listview");
#             }
#         });
#     };
#              </script>
#             </div>
#             <div class="sf_colsIn col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204038_Col02">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="navItemLayout">
#         <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204040_Col00">
#          <nav role="navigation">
#           <ul class="main-navigation">
#            <li class="">
#             <a href="/redirect-pages/mega-menu/emergencies" target="_self">
#              Emergencies
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#         <div class="container">
#          <div class="row">
#           <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204040_Col01">
#            <div class="row" data-sf-element="Row">
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204090_Col00">
#              <div class="main-navigation--wrapper">
#               <ul class="main-navigation navVertical">
#                <li class="">
#                 <a href="/redirect-pages/mega-menu/emergencies/emergencies" target="_self">
#                  Focus on »
#                 </a>
#                 <ul class="sub-level">
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/emergencies/afghanistan-crisis" target="_self">
#                    Afghanistan crisis
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/emergencies/novel-coronavirus-(2019-ncov)" target="_self">
#                    COVID-19 pandemic
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/emergencies/crisis-in-northern-ethiopia" target="_self">
#                    Northern Ethiopia crisis
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/emergencies/syrian-arab-republic" target="_self">
#                    Syria crisis
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/emergencies/ukraine-emergency" target="_self">
#                    Ukraine emergency
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/emergencies/monkeypox-outbreak" target="_self">
#                    Monkeypox outbreak
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/emergencies/greater-horn-of-africa-crisis" target="_self">
#                    Greater Horn of Africa crisis
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204090_Col01">
#              <div class="main-navigation--wrapper">
#               <ul class="main-navigation navVertical">
#                <li class="">
#                 <a href="/redirect-pages/mega-menu/emergencies/news" target="_self">
#                  Latest »
#                 </a>
#                 <ul class="sub-level">
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/news/disease-outbreak-news" target="_self">
#                    Disease Outbreak News
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/news/travel--advice" target="_self">
#                    Travel advice
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/news/situation-reports" target="_self">
#                    Situation reports
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/news/weekly-epidemiological-record" target="_self">
#                    Weekly Epidemiological Record
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204090_Col02">
#              <div class="main-navigation--wrapper">
#               <ul class="main-navigation navVertical">
#                <li class="">
#                 <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies" target="_self">
#                  WHO in emergencies »
#                 </a>
#                 <ul class="sub-level">
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/surveillance" target="_self">
#                    Surveillance
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/research-development" target="_self">
#                    Research
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/funding" target="_self">
#                    Funding
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/partners" target="_self">
#                    Partners
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/operations" target="_self">
#                    Operations
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/independent-oversight-and-advisory--committee" target="_self">
#                    Independent Oversight and Advisory Committee
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/emergencies/who-in-emergencies/who-s-health-emergency-appeal-2023" target="_self">
#                    WHO's Health Emergency Appeal 2023
#                   </a>
#                  </li>
#                 </ul>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204090_Col03">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="navItemLayout">
#         <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_T75121FDA215_Col00">
#          <nav role="navigation">
#           <ul class="main-navigation">
#            <li class="">
#             <a href="/redirect-pages/mega-menu/data" target="_self">
#              Data
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#         <div class="container">
#          <div class="row">
#           <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_T75121FDA215_Col01">
#            <div class="row" data-sf-element="Row">
#             <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_T75121FDA217_Col00">
#              <div class="main-navigation--wrapper">
#               <ul class="main-navigation navVertical">
#                <li class="">
#                 <a href="/redirect-pages/mega-menu/data/data-at-who" target="_self">
#                  Data at WHO »
#                 </a>
#                 <ul class="sub-level">
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/data/data-at-who/global-healthestimates" target="_self">
#                    Global Health Estimates
#                   </a>
#                  </li>
#                  <li class="">
#                   <a href="/redirect-pages/mega-menu/data/data-at-who/health-sdgs" target="_self">
#                    Health SDGs
#                   </a>
#                  </li>
#                  <li class="">
# ...
#             <li class="">
#              <a href="/redirect-pages/footer/about-us/library" target="_self">
#               Library
#              </a>
#             </li>
#             <li class="">
#              <a href="/redirect-pages/footer/about-us/procurement" target="_self">
#               Procurement
#              </a>
#             </li>
#             <li class="">
#              <a href="/redirect-pages/footer/about-us/publications" target="_self">
#               Publications
#              </a>
#             </li>
#             <li class="">
#              <a href="/redirect-pages/footer/about-us/frequently-asked-questions" target="_self">
#               Frequently asked questions
#              </a>
#             </li>
#             <li class="">
#              <a href="/redirect-pages/footer/about-us/contact-us" target="_self">
#               Contact us
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="sf_colsIn col-sm-3 col-md-3 centered-on-mobile" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Footer_T75121FDA153_Col01">
#         <div class="sf-content-block content-block">
#          <div>
#           <div class="button button-dark-background" style="text-align:center;">
#            <a href="/news-room/newsletters">
#             Subscribe to our newsletters
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="row" data-sf-element="Row">
#        <div class="sf_colsIn col-md-12" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Footer_T75121FDA199_Col00">
#        </div>
#       </div>
#      </div>
#      <div class="footer-logo">
#       <a href="/" title="Home">
#        <img alt="Home" class="logo" src="/ResourcePackages/WHO/assets/dist/images/logos/en/h-logo-white.svg"/>
#       </a>
#      </div>
#     </div>
#     <div class="bottom-footer">
#      <div class="container">
#       <div class="row">
#        <div class="col-md-4">
#         <div class="sf-content-block content-block footerlinkleft">
#          <div>
#           <span class="footerlinka">
#            <a href="/about/policies/privacy">
#             Privacy Legal Notice
#            </a>
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="col-md-4">
#         <div class="sf-content-block content-block socialmedia-icons">
#          <div>
#           <a data-sf-ec-immutable="" href="https://www.youtube.com/user/who?sub_confirmation=1" target="_blank" title="Follow WHO on Youtube">
#            <svg viewbox="0 0 576 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M549.655 124.083c-6.281-23.65-24.787-42.276-48.284-48.597C458.781 64 288 64 288 64S117.22 64 74.629 75.486c-23.497 6.322-42.003 24.947-48.284 48.597-11.412 42.867-11.412 132.305-11.412 132.305s0 89.438 11.412 132.305c6.281 23.65 24.787 41.5 48.284 47.821C117.22 448 288 448 288 448s170.78 0 213.371-11.486c23.497-6.321 42.003-24.171 48.284-47.821 11.412-42.867 11.412-132.305 11.412-132.305s0-89.438-11.412-132.305zm-317.51 213.508V175.185l142.739 81.205-142.739 81.201z" fill="white">
#             </path>
#            </svg>
#           </a>
#           <a data-sf-ec-immutable="" href="https://twitter.com/intent/follow?source=followbutton&amp;variant=1.0&amp;screen_name=who" target="_blank" title="Follow WHO on Twitter">
#            <svg viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M459.37 151.716c.325 4.548.325 9.097.325 13.645 0 138.72-105.583 298.558-298.558 298.558-59.452 0-114.68-17.219-161.137-47.106 8.447.974 16.568 1.299 25.34 1.299 49.055 0 94.213-16.568 130.274-44.832-46.132-.975-84.792-31.188-98.112-72.772 6.498.974 12.995 1.624 19.818 1.624 9.421 0 18.843-1.3 27.614-3.573-48.081-9.747-84.143-51.98-84.143-102.985v-1.299c13.969 7.797 30.214 12.67 47.431 13.319-28.264-18.843-46.781-51.005-46.781-87.391 0-19.492 5.197-37.36 14.294-52.954 51.655 63.675 129.3 105.258 216.365 109.807-1.624-7.797-2.599-15.918-2.599-24.04 0-57.828 46.782-104.934 104.934-104.934 30.213 0 57.502 12.67 76.67 33.137 23.715-4.548 46.456-13.32 66.599-25.34-7.798 24.366-24.366 44.833-46.132 57.827 21.117-2.273 41.584-8.122 60.426-16.243-14.292 20.791-32.161 39.308-52.628 54.253z" fill="white">
#             </path>
#            </svg>
#           </a>
#           <a data-sf-ec-immutable="" href="https://www.facebook.com/WHO" target="_blank" title="Follow WHO on Facebook">
#            <svg viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M279.14 288l14.22-92.66h-88.91v-60.13c0-25.35 12.42-50.06 52.24-50.06h40.42V6.26S260.43 0 225.36 0c-73.22 0-121.08 44.38-121.08 124.72v70.62H22.89V288h81.39v224h100.17V288z" fill="white">
#             </path>
#            </svg>
#           </a>
#           <a data-sf-ec-immutable="" href="https://instagram.com/who" target="_blank" title="Follow WHO on Instagram">
#            <svg viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M224.1 141c-63.6 0-114.9 51.3-114.9 114.9s51.3 114.9 114.9 114.9S339 319.5 339 255.9 287.7 141 224.1 141zm0 189.6c-41.1 0-74.7-33.5-74.7-74.7s33.5-74.7 74.7-74.7 74.7 33.5 74.7 74.7-33.6 74.7-74.7 74.7zm146.4-194.3c0 14.9-12 26.8-26.8 26.8-14.9 0-26.8-12-26.8-26.8s12-26.8 26.8-26.8 26.8 12 26.8 26.8zm76.1 27.2c-1.7-35.9-9.9-67.7-36.2-93.9-26.2-26.2-58-34.4-93.9-36.2-37-2.1-147.9-2.1-184.9 0-35.8 1.7-67.6 9.9-93.9 36.1s-34.4 58-36.2 93.9c-2.1 37-2.1 147.9 0 184.9 1.7 35.9 9.9 67.7 36.2 93.9s58 34.4 93.9 36.2c37 2.1 147.9 2.1 184.9 0 35.9-1.7 67.7-9.9 93.9-36.2 26.2-26.2 34.4-58 36.2-93.9 2.1-37 2.1-147.8 0-184.8zM398.8 388c-7.8 19.6-22.9 34.7-42.6 42.6-29.5 11.7-99.5 9-132.1 9s-102.7 2.6-132.1-9c-19.6-7.8-34.7-22.9-42.6-42.6-11.7-29.5-9-99.5-9-132.1s-2.6-102.7 9-132.1c7.8-19.6 22.9-34.7 42.6-42.6 29.5-11.7 99.5-9 132.1-9s102.7-2.6 132.1 9c19.6 7.8 34.7 22.9 42.6 42.6 11.7 29.5 9 99.5 9 132.1s2.7 102.7-9 132.1z" fill="white">
#             </path>
#            </svg>
#           </a>
#           <a data-sf-ec-immutable="" href="https://www.linkedin.com/company/world-health-organization" target="_blank" title="Follow WHO on LinkedIn">
#            <svg viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M416 32H31.9C14.3 32 0 46.5 0 64.3v383.4C0 465.5 14.3 480 31.9 480H416c17.6 0 32-14.5 32-32.3V64.3c0-17.8-14.4-32.3-32-32.3zM135.4 416H69V202.2h66.5V416zm-33.2-243c-21.3 0-38.5-17.3-38.5-38.5S80.9 96 102.2 96c21.2 0 38.5 17.3 38.5 38.5 0 21.3-17.2 38.5-38.5 38.5zm282.1 243h-66.4V312c0-24.8-.5-56.7-34.5-56.7-34.6 0-39.9 27-39.9 54.9V416h-66.4V202.2h63.7v29.2h.9c8.9-16.8 30.6-34.5 62.9-34.5 67.2 0 79.7 44.3 79.7 101.9V416z" fill="white">
#             </path>
#            </svg>
#           </a>
#           <a data-sf-ec-immutable="" href="https://www.snapchat.com/add/who" target="_blank" title="Follow WHO on Snapchat">
#            <svg viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M496.926,366.6c-3.373-9.176-9.8-14.086-17.112-18.153-1.376-.806-2.641-1.451-3.72-1.947-2.182-1.128-4.414-2.22-6.634-3.373-22.8-12.09-40.609-27.341-52.959-45.42a102.889,102.889,0,0,1-9.089-16.12c-1.054-3.013-1-4.724-.248-6.287a10.221,10.221,0,0,1,2.914-3.038c3.918-2.591,7.96-5.22,10.7-6.993,4.885-3.162,8.754-5.667,11.246-7.44,9.362-6.547,15.909-13.5,20-21.278a42.371,42.371,0,0,0,2.1-35.191c-6.2-16.318-21.613-26.449-40.287-26.449a55.543,55.543,0,0,0-11.718,1.24c-1.029.224-2.059.459-3.063.72.174-11.16-.074-22.94-1.066-34.534-3.522-40.758-17.794-62.123-32.674-79.16A130.167,130.167,0,0,0,332.1,36.443C309.515,23.547,283.91,17,256,17S202.6,23.547,180,36.443a129.735,129.735,0,0,0-33.281,26.783c-14.88,17.038-29.152,38.44-32.673,79.161-.992,11.594-1.24,23.435-1.079,34.533-1-.26-2.021-.5-3.051-.719a55.461,55.461,0,0,0-11.717-1.24c-18.687,0-34.125,10.131-40.3,26.449a42.423,42.423,0,0,0,2.046,35.228c4.105,7.774,10.652,14.731,20.014,21.278,2.48,1.736,6.361,4.24,11.246,7.44,2.641,1.711,6.5,4.216,10.28,6.72a11.054,11.054,0,0,1,3.3,3.311c.794,1.624.818,3.373-.36,6.6a102.02,102.02,0,0,1-8.94,15.785c-12.077,17.669-29.363,32.648-51.434,44.639C32.355,348.608,20.2,352.75,15.069,366.7c-3.868,10.528-1.339,22.506,8.494,32.6a49.137,49.137,0,0,0,12.4,9.387,134.337,134.337,0,0,0,30.342,12.139,20.024,20.024,0,0,1,6.126,2.741c3.583,3.137,3.075,7.861,7.849,14.78a34.468,34.468,0,0,0,8.977,9.127c10.019,6.919,21.278,7.353,33.207,7.811,10.776.41,22.989.881,36.939,5.481,5.778,1.91,11.78,5.605,18.736,9.92C194.842,480.951,217.707,495,255.973,495s61.292-14.123,78.118-24.428c6.907-4.24,12.872-7.9,18.489-9.758,13.949-4.613,26.163-5.072,36.939-5.481,11.928-.459,23.187-.893,33.206-7.812a34.584,34.584,0,0,0,10.218-11.16c3.434-5.84,3.348-9.919,6.572-12.771a18.971,18.971,0,0,1,5.753-2.629A134.893,134.893,0,0,0,476.02,408.71a48.344,48.344,0,0,0,13.019-10.193l.124-.149C498.389,388.5,500.708,376.867,496.926,366.6Zm-34.013,18.277c-20.745,11.458-34.533,10.23-45.259,17.137-9.114,5.865-3.72,18.513-10.342,23.076-8.134,5.617-32.177-.4-63.239,9.858-25.618,8.469-41.961,32.822-88.038,32.822s-62.036-24.3-88.076-32.884c-31-10.255-55.092-4.241-63.239-9.858-6.609-4.563-1.24-17.211-10.341-23.076-10.739-6.907-24.527-5.679-45.26-17.075-13.206-7.291-5.716-11.8-1.314-13.937,75.143-36.381,87.133-92.552,87.666-96.719.645-5.046,1.364-9.014-4.191-14.148-5.369-4.96-29.189-19.7-35.8-24.316-10.937-7.638-15.748-15.264-12.2-24.638,2.48-6.485,8.531-8.928,14.879-8.928a27.643,27.643,0,0,1,5.965.67c12,2.6,23.659,8.617,30.392,10.242a10.749,10.749,0,0,0,2.48.335c3.6,0,4.86-1.811,4.612-5.927-.768-13.132-2.628-38.725-.558-62.644,2.84-32.909,13.442-49.215,26.04-63.636,6.051-6.932,34.484-36.976,88.857-36.976s82.88,29.92,88.931,36.827c12.611,14.421,23.225,30.727,26.04,63.636,2.071,23.919.285,49.525-.558,62.644-.285,4.327,1.017,5.927,4.613,5.927a10.648,10.648,0,0,0,2.48-.335c6.745-1.624,18.4-7.638,30.4-10.242a27.641,27.641,0,0,1,5.964-.67c6.386,0,12.4,2.48,14.88,8.928,3.546,9.374-1.24,17-12.189,24.639-6.609,4.612-30.429,19.343-35.8,24.315-5.568,5.134-4.836,9.1-4.191,14.149.533,4.228,12.511,60.4,87.666,96.718C468.629,373.011,476.119,377.524,462.913,384.877Z" fill="white">
#             </path>
#            </svg>
#           </a>
#           <a data-sf-ec-immutable="" href="https://www.tiktok.com/@who?lang=en" target="_blank" title="Follow WHO on TikTok">
#            <svg viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M448,209.91a210.06,210.06,0,0,1-122.77-39.25V349.38A162.55,162.55,0,1,1,185,188.31V278.2a74.62,74.62,0,1,0,52.23,71.18V0l88,0a121.18,121.18,0,0,0,1.86,22.17h0A122.18,122.18,0,0,0,381,102.39a121.43,121.43,0,0,0,67,20.14Z" fill="white">
#             </path>
#            </svg>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col-md-4 copyright">
#         <span>
#          ©
#         </span>
#         2023
#         <div class="sf-content-block content-block">
#          <div>
#           <a href="/about/policies/terms-of-use">
#            WHO
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script>
#    window.__define = window.define;
#         window.__require = window.require;
#         window.define = undefined;
#         window.require = undefined;
#   </script>
#   <script src="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.all.min.js" type="text/javascript">
#   </script>
#   <script src="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.timezones.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/gsap.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/ScrollTrigger.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/ScrollToPlugin.min.js" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/parallax.min.js?package=WHO" type="text/javascript">
#   </script>
#   <script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend.Search/Mvc/Scripts/SearchBox/Search-box.min.js?package=WHO&amp;v=OTk4MDgwOTIw" type="text/javascript">
#   </script>
#   <script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend.Navigation/Mvc/Scripts/LanguageSelector/language-selector.min.js?package=WHO&amp;v=MTQuMy44MDI2LjA%3d" type="text/javascript">
#   </script>
#   <script src="/Mvc/Scripts/ContentBlock/content-block.min.js?package=WHO" type="text/javascript">
#   </script>
#   <script src="/Mvc/Scripts/HeroImage/responsive-background-image.min.js?package=WHO" type="text/javascript">
#   </script>
#   <script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend/Mvc/Scripts/GHO/utils.min.js?package=WHO&amp;v=LTY1ODA2NjUzNQ%3d%3d" type="text/javascript">
#   </script>
#   <script id="PersonalizationTracker" type="application/json">
#    {"IsPagePersonalizationTarget":false,"IsUrlPersonalizationTarget":false,"PageId":"6543db4e-ce8c-4a69-8f0f-f205195f7488"}
#   </script>
#   <script src="/WebResource.axd?d=Oiw5o8i74rDb2VpVaCaMStPoJ1dBeSniQ1UcN-tajp7S6UQI4QFVCojlg1ewuf339ZIyq0NtnQlSiEw1RQXcWIVwl_-LxzVLlNCkT-5fM3qvVhZCKMRq6X6cWc42Aw4Db6sa87yi7j5Hio4wozQZMklgyIbXX4yGQn_Sh0nCPeRw8nypcGpUIdT0MqtRIOGgRLfw327mU3tc3-bA3UOOd_v176Q1&amp;t=638156688400000000" type="text/javascript">
#   </script>
#   <input data-sf-role="en" type="hidden" value="https://www.who.int/data/gho/data/themes/air-pollution/who-air-quality-database/2022"/>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/slicknav.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/auto-complete.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/match-height.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/lazy.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/modernizr-custom.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/select2.full.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/accordion-footer-list.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/main.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/main-navigation.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/geo-navigation.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/image-resolution.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script type="application/ld+json">
#    {
#             "@context": "http://schema.org",
#             "@type": "WebPage",
#             "name": "Air quality database 2022",
#             "description": "WHO&#39;s air quality database compiles data on ground measurements of annual mean concentrations of particulate matter of a diameter equal to or smaller than 10 μm (PM10) or equal to or smaller than 2.5 μm (PM2.5) which aim at representing an average for the city or town as a whole, rather than for individual stations. The database currently hosts 4300 human settlements in 108 countries and is updated on a regular basis."
#             }
#   </script>
#   <script>
#    // Picture element HTML5 shiv
#         document.createElement("picture");
#   </script>
#   <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/picturefill.min.js?v=14.0.7729.21936" type="text/javascript">
#   </script>
#   <script>
#    window.define = window.__define;
#         window.require = window.__require;
#         window.__define = undefined;
#         window.__require = undefined;
#   </script>
#  </body>
# </html>

# %%
links2
# Out:
# [<p>This database was release in April 2022 (5th edition) and the years of measurement range mostly from 2010 to 2019.</p>,
#  <p>The WHO air quality database compiles data on ground measurements of annual mean concentrations of nitrogen dioxide (NO<sub>2</sub>), particulate matter of a diameter equal or smaller than 10 μm (PM<sub>10</sub>) or equal or smaller than 2.5 μm (PM<sub>2.5</sub>) which aim at representing an average for the city or town as a whole, rather than for individual stations. Both groups of pollutants originate mainly from human activities related to fossil fuel combustion.</p>,
#  <p>The 2022 update (Fifth Version) database was released in April 2022 and hosts data on air quality for over 600 human settlements in more than 100 countries.</p>,
#  <p>The data compiled in this database is used as input to derive the Sustainable Development Goal Indicator 11.6.2, Air quality in cities, for which WHO is custodial agency.</p>,
#  <p><span style="background-color:initial;color:#333333;font-family:inherit;font-size:inherit;text-transform:inherit;white-space:inherit;word-spacing:normal;caret-color:auto;">The primary sources of data were official reports of countries sent to WHO upon request, official national and subnational reports and national and subnational websites that contain measurements of PM10 or PM2.5 and ground measurements compiled in the framework of the Global Burden of Disease project. For NO2, ground measurements compiled for research by <a data-sf-ec-immutable="" href="https://pubs.acs.org/doi/10.1021/acs.est.7b01148" target="_blank">Larkin et al. in 2017</a> were obtained. Measurements reported by the following regional networks were also used: Clean Air for Asia, the Air quality e-reporting database of the European Environment Agency for Europe and the AirNow Programme from the United States embassies and consulates. If such official data were not available, values from UN Agencies, Development agencies and peer-reviewed journals were used. </span></p>,
#  <p></p>,
#  <p>Related pages</p>,
#  <p><p><a href="https://cdn.who.int/media/docs/default-source/air-pollution-documents/air-quality-and-health/who_aap_2021_v9_11august2022.xlsx?sfvrsn=9035996c_3" target="_blank">Excel version of the database - Ambient (outdoor) air quality database, by country and city</a></p></p>,
#  <p><a href="https://cdn.who.int/media/docs/default-source/air-pollution-documents/air-quality-and-health/who_aap_2021_v9_11august2022.xlsx?sfvrsn=9035996c_3" target="_blank">Excel version of the database - Ambient (outdoor) air quality database, by country and city</a></p>,
#  <p><a data-sf-ec-immutable="" href="https://whoairquality.shinyapps.io/AmbientAirQualityDatabase/" target="_blank">The App includes built-in WHO data, originating from the WHO Ambient Air Quality Database.</a></p>,
#  <p><a href="https://cdn.who.int/media/docs/default-source/air-pollution-documents/air-quality-and-health/methodology_who-air-quality-database-2022.pdf?sfvrsn=bdcf9241_10" target="_blank">Methods used for compiling the database</a></p>,
#  <p><a data-sf-ec-immutable="" data-sf-marked="" href="https://www.who.int/news/item/04-04-2022-billions-of-people-still-breathe-unhealthy-air-new-who-data" target="_blank">News Release - WHO's Air Quality Database, Update April 2022</a></p>,
#  <p><a href="/news-room/questions-and-answers/item/who-s-fifth-who-air-quality-database-of-over-6000-cities-updated-april-2022">Frequently asked questions about the database</a></p>,
#  <p><a href="https://cdn.who.int/media/docs/default-source/air-pollution-documents/air-quality-and-health/country-groupings-database-2022.pdf?sfvrsn=4a43dfa8_10" style="font-family:inherit;text-align:inherit;text-transform:inherit;white-space:inherit;word-spacing:normal;font-size:inherit;" target="_blank">Country grouping</a></p>,
#  <p>The WHO global ambient air quality database is continuously being updated. If you are an official air quality data provider at either the country or city level, please use this template to submit the data to WHO.</p>,
#  <p><a href="https://cdn.who.int/media/docs/default-source/air-pollution-documents/air-quality-and-health/who_database_template_2022.xlsx?sfvrsn=c948d71a_11" target="_blank">Data template for the WHO air quality database 2022</a></p>,
#  <p>Related factsheet</p>,
#  <p>Related tools</p>,
#  <p>Related teams</p>,
#  <p>Related health topic</p>,
#  <p>Additional Resources</p>]

# %%
path=links2[7].p.a['href']

# %%
path
# Out:
# 'https://cdn.who.int/media/docs/default-source/air-pollution-documents/air-quality-and-health/who_aap_2021_v9_11august2022.xlsx?sfvrsn=9035996c_3'

# %%
  r = requests.get(path)

# %%
r
# Out:
# <Response [200]>

# %%
#C:\Users\hp\Desktop
f_name='air_quality'

with open(f'C:/Users/hp/Desktop/Data_Science_Internship/New_Web/{f_name}.xlsx', 'wb') as f:
    f.write(r.content)

# %%
import pandas as pd

Air=pd.read_excel('New_Web/air_quality.xlsx' ,sheet_name=1)

# %%
Air
# Out:
#                          WHO Region ISO3      WHO Country Name  \
# 0      Eastern Mediterranean Region  AFG           Afghanistan
# 1                   European Region  ALB               Albania
# 2                   European Region  ALB               Albania
# 3                   European Region  ALB               Albania
# 4                   European Region  ALB               Albania
# 5                   European Region  ALB               Albania
# 6                   European Region  ALB               Albania
# 7                   European Region  ALB               Albania
# 8                   European Region  ALB               Albania
# 9                   European Region  ALB               Albania
# 10                  European Region  ALB               Albania
# 11                  European Region  ALB               Albania
# 12                  European Region  ALB               Albania
# 13                  European Region  AND               Andorra
# 14                  European Region  AND               Andorra
# 15                  European Region  AND               Andorra
# 16                  European Region  AND               Andorra
# 17                  European Region  AND               Andorra
# 18                  European Region  AND               Andorra
# 19                  European Region  AND               Andorra
# 20     Eastern Mediterranean Region  ARE  United Arab Emirates
# 21     Eastern Mediterranean Region  ARE  United Arab Emirates
# 22     Eastern Mediterranean Region  ARE  United Arab Emirates
# 23     Eastern Mediterranean Region  ARE  United Arab Emirates
# 24     Eastern Mediterranean Region  ARE  United Arab Emirates
# 25     Eastern Mediterranean Region  ARE  United Arab Emirates
# 26     Eastern Mediterranean Region  ARE  United Arab Emirates
# 27     Eastern Mediterranean Region  ARE  United Arab Emirates
# 28     Eastern Mediterranean Region  ARE  United Arab Emirates
# 29     Eastern Mediterranean Region  ARE  United Arab Emirates
# ...                             ...  ...                   ...
# 32161                African Region  ZAF          South Africa
# 32162                African Region  ZAF          South Africa
# 32163                African Region  ZAF          South Africa
# 32164                African Region  ZAF          South Africa
# 32165                African Region  ZAF          South Africa
# 32166                African Region  ZAF          South Africa
# 32167                African Region  ZAF          South Africa
# 32168                African Region  ZAF          South Africa
# 32169                African Region  ZAF          South Africa
# 32170                African Region  ZAF          South Africa
# 32171                African Region  ZAF          South Africa
# 32172                African Region  ZAF          South Africa
# 32173                African Region  ZAF          South Africa
# 32174                African Region  ZAF          South Africa
# 32175                African Region  ZAF          South Africa
# 32176                African Region  ZAF          South Africa
# 32177                African Region  ZAF          South Africa
# 32178                African Region  ZAF          South Africa
# 32179                African Region  ZAF          South Africa
# 32180                African Region  ZAF          South Africa
# 32181                African Region  ZAF          South Africa
# 32182                African Region  ZAF          South Africa
# 32183                African Region  ZAF          South Africa
# 32184                African Region  ZAF          South Africa
# 32185                African Region  ZAF          South Africa
# 32186                African Region  ZAF          South Africa
# 32187                African Region  ZAF          South Africa
# 32188                African Region  ZAF          South Africa
# 32189                African Region  ZAF          South Africa
# 32190                African Region  ZAF          South Africa
#
#          City or Locality  Measurement Year  PM2.5 (μg/m3)  PM10 (μg/m3)  \
# 0                   Kabul              2019         119.77           NaN
# 1                  Durres              2015            NaN         17.65
# 2                  Durres              2016          14.32         24.56
# 3                 Elbasan              2015            NaN           NaN
# 4                 Elbasan              2016            NaN           NaN
# 5                 Elbasan              2017            NaN           NaN
# 6                   Korce              2015          30.34         45.31
# 7                   Korce              2016          28.64         40.21
# 8                   Vlore              2014            NaN         15.25
# 9                   Vlore              2015            NaN         19.39
# 10                  Vlore              2016            NaN         22.71
# 11                  Vlore              2019          10.32           NaN
# 12                  Vrith              2015          13.24         19.52
# 13     Escaldes-Engordany              2012            NaN         27.50
# 14     Escaldes-Engordany              2014            NaN         25.03
# 15     Escaldes-Engordany              2015            NaN         27.04
# 16     Escaldes-Engordany              2016            NaN         26.26
# 17     Escaldes-Engordany              2017            NaN         26.30
# 18     Escaldes-Engordany              2018            NaN         23.20
# 19     Escaldes-Engordany              2019            NaN         24.58
# 20              Abu Dhabi              2011            NaN        158.18
# 21              Abu Dhabi              2012            NaN        165.30
# 22              Abu Dhabi              2013            NaN        143.75
# 23              Abu Dhabi              2014            NaN        108.60
# 24              Abu Dhabi              2015            NaN        149.75
# 25              Abu Dhabi              2017          32.79        122.17
# 26              Abu Dhabi              2018          49.13        134.29
# 27              Abu Dhabi              2019          44.40        108.52
# 28              Abu Dhabi              2020            NaN        111.49
# 29                  Ajman              2017            NaN           NaN
# ...                   ...               ...            ...           ...
# 32161        Umkhanyakude              2012            NaN         22.60
# 32162        Umkhanyakude              2013            NaN         21.37
# 32163        Umkhanyakude              2020            NaN         24.92
# 32164           Uthungulu              2011            NaN         23.35
# 32165           Uthungulu              2012            NaN         26.65
# 32166           Uthungulu              2013            NaN         26.90
# 32167           Uthungulu              2014            NaN         28.03
# 32168           Uthungulu              2015            NaN         30.50
# 32169           Uthungulu              2016            NaN         24.63
# 32170           Uthungulu              2019           6.91         19.89
# 32171           Uthungulu              2020            NaN         20.07
# 32172           Uthungulu              2021            NaN         17.58
# 32173           Waterberg              2011          70.42         64.54
# 32174           Waterberg              2012          43.31         85.22
# 32175           Waterberg              2013          17.82         47.49
# 32176           Waterberg              2014          12.87         29.58
# 32177           Waterberg              2015          10.59         28.64
# 32178           Waterberg              2016          12.82         30.56
# 32179           Waterberg              2017          15.48         41.72
# 32180           Waterberg              2018          16.62         43.91
# 32181           Waterberg              2019          16.33         48.62
# 32182           Waterberg              2020          15.57         41.06
# 32183           Waterberg              2021          18.86         44.71
# 32184          West Coast              2011            NaN         22.22
# 32185          West Coast              2014            NaN         23.98
# 32186          West Coast              2015           7.47         24.64
# 32187          West Coast              2016           8.42         33.28
# 32188          West Coast              2017           6.83         20.49
# 32189          West Coast              2018           6.10         17.99
# 32190           West Rand              2016            NaN           NaN
#
#        NO2 (μg/m3)  PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 0              NaN                   18.000000                         NaN
# 1            26.63                         NaN                         NaN
# 2            24.78                         NaN                         NaN
# 3            23.96                         NaN                         NaN
# 4            26.26                         NaN                         NaN
# 5            24.70                         NaN                         NaN
# 6              NaN                         NaN                         NaN
# 7            12.52                         NaN                         NaN
# 8              NaN                         NaN                         NaN
# 9            14.18                         NaN                         NaN
# 10             NaN                         NaN                         NaN
# 11             NaN                         NaN                         NaN
# 12            9.57                         NaN                         NaN
# 13           31.64                         NaN                         NaN
# 14           27.62                         NaN                         NaN
# 15           26.65                         NaN                         NaN
# 16           26.98                         NaN                         NaN
# 17           28.74                         NaN                         NaN
# 18           26.55                         NaN                         NaN
# 19           31.01                         NaN                         NaN
# 20           36.72                         NaN                         NaN
# 21           38.22                         NaN                         NaN
# 22           37.74                         NaN                         NaN
# 23           39.58                         NaN                         NaN
# 24           38.05                         NaN                         NaN
# 25           30.05                         NaN                         NaN
# 26           31.24                   88.293851                         NaN
# 27           30.89                   89.000000                         NaN
# 28           25.35                         NaN                         NaN
# 29           50.33                         NaN                         NaN
# ...            ...                         ...                         ...
# 32161          NaN                   75.000000                        75.0
# 32162          NaN                   75.000000                        75.0
# 32163          NaN                   75.000000                        75.0
# 32164          NaN                   75.000000                        75.0
# 32165          NaN                   75.000000                        75.0
# 32166          NaN                   75.000000                        75.0
# 32167          NaN                   75.000000                        75.0
# 32168          NaN                   75.000000                        75.0
# 32169          NaN                   75.000000                        75.0
# 32170         9.13                   75.000000                        75.0
# 32171        10.36                   75.000000                        75.0
# 32172        11.85                   75.000000                        75.0
# 32173        10.12                   75.000000                        75.0
# 32174        11.62                   75.000000                        75.0
# 32175        13.26                   75.000000                        75.0
# 32176        12.03                   75.000000                        75.0
# 32177        15.89                   75.000000                        75.0
# 32178        40.41                   75.000000                        75.0
# 32179        13.19                   75.000000                        75.0
# 32180        13.69                   75.000000                        75.0
# 32181        13.90                   75.000000                        75.0
# 32182         8.86                   75.000000                        75.0
# 32183        18.37                   75.000000                        75.0
# 32184        16.36                   75.000000                        75.0
# 32185        10.67                   75.000000                        75.0
# 32186         7.64                   75.000000                        75.0
# 32187         7.27                   75.000000                        75.0
# 32188         8.72                   75.000000                        75.0
# 32189         7.15                   75.000000                        75.0
# 32190        17.85                         NaN                         NaN
#
#        NO2 temporal coverage (%)  \
# 0                            NaN
# 1                      83.961187
# 2                      87.932605
# 3                      97.853881
# 4                      96.049636
# 5                      89.292237
# 6                            NaN
# 7                      89.287341
# 8                            NaN
# 9                      78.470320
# 10                           NaN
# 11                           NaN
# 12                     86.255708
# 13                    100.000000
# 14                    100.000000
# 15                     94.554795
# 16                     94.968124
# 17                     95.102740
# 18                     93.390411
# 19                     92.180365
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# ...                          ...
# 32161                        NaN
# 32162                        NaN
# 32163                        NaN
# 32164                        NaN
# 32165                        NaN
# 32166                        NaN
# 32167                        NaN
# 32168                        NaN
# 32169                        NaN
# 32170                  75.000000
# 32171                  75.000000
# 32172                  75.000000
# 32173                  75.000000
# 32174                  75.000000
# 32175                  75.000000
# 32176                  75.000000
# 32177                  75.000000
# 32178                  75.000000
# 32179                  75.000000
# 32180                  75.000000
# 32181                  75.000000
# 32182                  75.000000
# 32183                  75.000000
# 32184                  75.000000
# 32185                  75.000000
# 32186                  75.000000
# 32187                  75.000000
# 32188                  75.000000
# 32189                  75.000000
# 32190                  75.000000
#
#                                                Reference  \
# 0      U.S. Department of State, United States Enviro...
# 1       European Environment Agency (downloaded in 2021)
# 2       European Environment Agency (downloaded in 2021)
# 3       European Environment Agency (downloaded in 2021)
# 4       European Environment Agency (downloaded in 2021)
# 5       European Environment Agency (downloaded in 2021)
# 6       European Environment Agency (downloaded in 2021)
# 7       European Environment Agency (downloaded in 2021)
# 8       European Environment Agency (downloaded in 2021)
# 9       European Environment Agency (downloaded in 2021)
# 10      European Environment Agency (downloaded in 2021)
# 11      European Environment Agency (downloaded in 2021)
# 12      European Environment Agency (downloaded in 2021)
# 13      European Environment Agency (downloaded in 2021)
# 14      European Environment Agency (downloaded in 2021)
# 15      European Environment Agency (downloaded in 2021)
# 16      European Environment Agency (downloaded in 2021)
# 17      European Environment Agency (downloaded in 2021)
# 18      European Environment Agency (downloaded in 2021)
# 19      European Environment Agency (downloaded in 2021)
# 20                        Environment Agency - Abu Dhabi
# 21                        Environment Agency - Abu Dhabi
# 22                        Environment Agency - Abu Dhabi
# 23                        Environment Agency - Abu Dhabi
# 24                        Environment Agency - Abu Dhabi
# 25     Statistics Center - Abu Dhabi from Environment...
# 26     Statistics Center - Abu Dhabi from Environment...
# 27     Statistics Center - Abu Dhabi from Environment...
# 28     Statistics Center - Abu Dhabi from Environment...
# 29     Statistics Center - Abu Dhabi from Environment...
# ...                                                  ...
# 32161       South African Air Quality Information System
# 32162       South African Air Quality Information System
# 32163       South African Air Quality Information System
# 32164       South African Air Quality Information System
# 32165       South African Air Quality Information System
# 32166       South African Air Quality Information System
# 32167       South African Air Quality Information System
# 32168       South African Air Quality Information System
# 32169       South African Air Quality Information System
# 32170       South African Air Quality Information System
# 32171       South African Air Quality Information System
# 32172       South African Air Quality Information System
# 32173       South African Air Quality Information System
# 32174       South African Air Quality Information System
# 32175       South African Air Quality Information System
# 32176       South African Air Quality Information System
# 32177       South African Air Quality Information System
# 32178       South African Air Quality Information System
# 32179       South African Air Quality Information System
# 32180       South African Air Quality Information System
# 32181       South African Air Quality Information System
# 32182       South African Air Quality Information System
# 32183       South African Air Quality Information System
# 32184       South African Air Quality Information System
# 32185       South African Air Quality Information System
# 32186       South African Air Quality Information System
# 32187       South African Air Quality Information System
# 32188       South African Air Quality Information System
# 32189       South African Air Quality Information System
# 32190       South African Air Quality Information System
#
#                   Number and type of monitoring stations  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20     1 City Centre, 1 Industrial, 1 Road Side, 2 Ur...
# 21     1 City Centre, 2 Industrial, 1 Road Side, 2 Ur...
# 22     1 City Centre, 2 Industrial, 1 Road Side, 4 Ur...
# 23     1 City Centre, 2 Industrial, 1 Road Side, 4 Ur...
# 24     1 City Centre, 2 Industrial, 1 Road Side, 4 Ur...
# 25     1 down town, 2 Down Town, 3 Industrial, 2 Refe...
# 26     1 down town, 2 Down Town, 3 Industrial, 2 Refe...
# 27     1 down town, 2 Down Town, 3 Industrial, 2 Refe...
# 28     1 down town, 2 Down Town, 3 Industrial, 2 Refe...
# 29                                         1 Residential
# ...                                                  ...
# 32161                           1 Residential-Low income
# 32162                           1 Residential-Low income
# 32163                           1 Residential-Low income
# 32164                                            1 Urban
# 32165                                            1 Urban
# 32166                                            1 Urban
# 32167                                            1 Urban
# 32168                                            1 Urban
# 32169                                            1 Urban
# 32170  2 Background, 1 Peri-urban, 1 Residential-Low ...
# 32171  2 Background, 2 Peri-urban, 1 Residential-Low ...
# 32172                              2 Background, 1 Urban
# 32173                           1 Residential-Low income
# 32174                           1 Residential-Low income
# 32175  1 Residential-Low income, 2 Residential-Medium...
# 32176  1 Residential-Low income, 2 Residential-Medium...
# 32177  1 Residential-Low income, 2 Residential-Medium...
# 32178  1 Residential-Low income, 2 Residential-Medium...
# 32179         2 Residential-Medium/Upper income, 1 Urban
# 32180         2 Residential-Medium/Upper income, 1 Urban
# 32181         2 Residential-Medium/Upper income, 1 Urban
# 32182         2 Residential-Medium/Upper income, 1 Urban
# 32183         2 Residential-Medium/Upper income, 1 Urban
# 32184                  1 Residential-Medium/Upper income
# 32185                  1 Residential-Medium/Upper income
# 32186                  3 Residential-Medium/Upper income
# 32187                  2 Residential-Medium/Upper income
# 32188                  2 Residential-Medium/Upper income
# 32189                  2 Residential-Medium/Upper income
# 32190                                              1 N/A
#
#        Version of the database  Status
# 0                         2022     NaN
# 1                         2022     NaN
# 2                         2022     NaN
# 3                         2022     NaN
# 4                         2022     NaN
# 5                         2022     NaN
# 6                         2022     NaN
# 7                         2022     NaN
# 8                         2022     NaN
# 9                         2022     NaN
# 10                        2022     NaN
# 11                        2022     NaN
# 12                        2022     NaN
# 13                        2022     NaN
# 14                        2022     NaN
# 15                        2022     NaN
# 16                        2022     NaN
# 17                        2022     NaN
# 18                        2022     NaN
# 19                        2022     NaN
# 20                        2018     NaN
# 21                        2018     NaN
# 22                        2018     NaN
# 23                        2018     NaN
# 24                        2018     NaN
# 25                        2022     NaN
# 26                        2022     NaN
# 27                        2022     NaN
# 28                        2022     NaN
# 29                        2022     NaN
# ...                        ...     ...
# 32161                     2022     NaN
# 32162                     2022     NaN
# 32163                     2022     NaN
# 32164                     2022     NaN
# 32165                     2022     NaN
# 32166                     2022     NaN
# 32167                     2022     NaN
# 32168                     2022     NaN
# 32169                     2022     NaN
# 32170                     2022     NaN
# 32171                     2022     NaN
# 32172                     2022     NaN
# 32173                     2022     NaN
# 32174                     2022     NaN
# 32175                     2022     NaN
# 32176                     2022     NaN
# 32177                     2022     NaN
# 32178                     2022     NaN
# 32179                     2022     NaN
# 32180                     2022     NaN
# 32181                     2022     NaN
# 32182                     2022     NaN
# 32183                     2022     NaN
# 32184                     2022     NaN
# 32185                     2022     NaN
# 32186                     2022     NaN
# 32187                     2022     NaN
# 32188                     2022     NaN
# 32189                     2022     NaN
# 32190                     2022     NaN
#
# [32191 rows x 15 columns]
